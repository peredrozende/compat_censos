# %% [markdown]
# # Comparability for 2010-2022 Census Tracts in Buenos Aires

# %%
from utils import *

# %%
C1 = '2010'
C2 = '2022'
location = 'BuenosAires'

BASENAME = f'{C1}_{C2}_{location}' # Nome da compatibilização
NAME_C1 = f'{location}_{C1}' # Nome da primeira malha censitária
NAME_C2 = f'{location}_{C2}' # Nome da segunda malha censitária

# %% [markdown]
# ## 1. Census layers pre-processing
# The following cell pre-processes the census layers and only needs to run once

# %%
# Códigos de províncias
provs = ['02', '06']

# Criação das malhas
layer_2010 = makeCensusLayer('resources/conicet/Radios CONICET.gpkg',
                            id_column='COD_2010', 
                            layer='2010',
                            filter=provs,
                            len_higher_hierarchy=2,
                            geosys='WGS84')
layer_2022 = makeCensusLayer('resources/conicet/Radios CONICET.gpkg', 
                            id_column='COD_2022', 
                            layer='2022',
                            filter=provs,
                            len_higher_hierarchy=2,
                            geosys='WGS84')

# Exportação
layer_2010.to_parquet(f'results/{NAME_C1}.parquet')
layer_2022.to_parquet(f'results/{NAME_C2}.parquet')
# Out:
# 'makeCensusLayer' executed in 49.5307s.
# 'makeCensusLayer' executed in 57.5880s.

# %%
# Importing
layer_2010 = gpd.read_parquet(f'results/{NAME_C1}.parquet')
layer_2022 = gpd.read_parquet(f'results/{NAME_C2}.parquet')

# %% [markdown]
# ## 2. Comparability graph

# %%
G_compat = comparability_graph(layer_2010, layer_2022)
# Out:
# 'comparability_graph.makeGridUnion' executed in 80.8439s.
# 'getNeighborhoods' executed in 0.0559s.
# 'getNeighborhoods' executed in 0.0563s.
# 'comparability_graph.classifyGridChanges' executed in 8.2558s.
# 'comparability_graph.__init__' executed in 92.7089s.

# %%
G_compat.findMaintenances()
G_compat.findSplitings(threshold=0.8)

# Aplica séries de buffers
for b in [-20, -10]:
    G_compat.forceOverlay(buffer=b)

# Sobreposição de isolados restantes
G_compat.forceOverlay(buffer=0, use_all=True)
# Out:
# 'comparability_graph.findMaintenances' executed in 0.0293s.
# 'comparability_graph.findSplitings' executed in 0.8497s.
# 'comparability_graph.forceOverlay' executed in 5.3200s.
# 'comparability_graph.forceOverlay' executed in 4.5939s.
# 'comparability_graph.forceOverlay' executed in 0.0574s.

# %% [markdown]
# ## 3. Assessing gold standard

# %%
# Criação do grafo verdadeiro com dados do IBGE
df_comp = pd.read_csv('resources/conicet/comparability_2010_2022.csv', dtype={'COD_2010':str, 'COD_2022':str})

nodesA = [str(i[2:]) for i in G_compat.nodes() if i.startswith('A')]
nodesB = [str(i[2:]) for i in G_compat.nodes() if i.startswith('B')]
comp_2010_2022 = df_comp[['COD_2022','COD_2010']]
comp_2010_2022 = comp_2010_2022.query('COD_2022 in @nodesB | COD_2010 in @nodesA')

truth_graph = nx.Graph()

# Adiciona nós existentes
truth_graph.add_nodes_from(G_compat.nodes())

# Adiciona arestas verdadeiras
for _, r in comp_2010_2022.iterrows():
    truth_graph.add_edge(f"A.{r['COD_2010']}", f"B.{r['COD_2022']}")

# Remove nós excedentes
exceeding_nodes = [i for i in truth_graph.nodes() if i not in G_compat.nodes()]
truth_graph.remove_nodes_from(exceeding_nodes)

# %%
G_compat.assessEdges(ground_truth_graph=truth_graph)
# Out:
# 'comparability_graph.assessEdges' executed in 0.7035s.

# %% [markdown]
# ## 4. Export results

# %%
G_compat.exportCompatFiles(BASENAME, NAME_C1, NAME_C2)
G_compat.reportCompat(file=f'results/{BASENAME}_report')
# Out:
# 'comparability_graph.exportCompatFiles' executed in 9.2538s.
# 'comparability_graph.reportCompat' executed in 0.0699s.
# {'params': {'A/P ratio': 0.3,
#   'Lmin': [0.8],
#   'Buffers': [{'buffer': -20, 'use_all': False},
#    {'buffer': -10, 'use_all': False},
#    {'buffer': 0, 'use_all': True}]},
#  'layers': {'Setores C1': 23130, 'Setores C2': 27721},
#  'relationships': {'Total relationships': {'n': 27772, 'pct': 1},
#   '': {'n': 28, 'pct': 0.0010082097076191847},
#   'Divisão': {'n': 16465, 'pct': 0.5928633155696384},
#   'Manutenção': {'n': 10694, 'pct': 0.38506409333141295},
#   'Manutenção desassociada': {'n': 190, 'pct': 0.006841423015987325},
#   'Sobreposição (-10m)': {'n': 10, 'pct': 0.00036007489557828026},
#   'Sobreposição (-20m)': {'n': 385, 'pct': 0.01386288347976379}},
#  'operations': {'Total redesign operations': {'n': 23110, 'pct': 1},
#   '1:1': {'n': 19362, 'pct': 0.8378191259195154},
#   '1:n': {'n': 3733, 'pct': 0.16153180441367374},
#   'm:n': {'n': 13, 'pct': 0.0005625270445694504},
#   'n:1': {'n': 2, 'pct': 8.654262224145392e-05}},
#  'metrics': {'Inconsistent maintenance': {'n': 0, 'pct': 0.0},
#   'Inconsistent splitting': {'n': 24.0, 'pct': 0.0014576374126935925},
#   'Unconnected polygons': {'n': 0, 'pct': 0.0},
#   'Persistent unconnected': {'n': 0, 'pct': 0.0},
#   'Large redesigns': {'n': 0, 'pct': 0.0}},
#  'assessment': {'true positives': 27744,
#   'false positives': 0,
#   'false negatives': 28,
#   'recall': 0.9989917902923808,
#   'precision': 1.0,
#   'f1_score': 0.999495640896318}}

# %% [markdown]
# ## 5. Parameter refinement test

# %%
for r in range(1,21):
    apr = round(0.1*r,2)
    print('\nTESTING A/P RATIO = ', apr)
    G_compat.reset(ap_ratio=apr)
    G_compat.findMaintenances()
    G_compat.findSplitings(threshold=0.8)
    # Aplica séries de buffers
    for b in [-20, -10]:
        G_compat.forceOverlay(buffer=b)
    # Sobreposição de isolados restantes
    G_compat.forceOverlay(buffer=0, use_all=True)

    G_compat.assessEdges(ground_truth_graph=truth_graph)

    G_compat.exportCompatFiles(BASENAME, NAME_C1, NAME_C2, save_files=False)
    G_compat.reportCompat(file=f'results/params/{BASENAME}_apr{str(apr).replace(".",",")}_report')
# Out:
# TESTING A/P RATIO =  0.1
# 'comparability_graph.reset' executed in 3.7044s.
# 'comparability_graph.findMaintenances' executed in 0.0247s.
# 'comparability_graph.findSplitings' executed in 0.8292s.
# 'comparability_graph.forceOverlay' executed in 5.1535s.
# 'comparability_graph.forceOverlay' executed in 4.6673s.
# 'comparability_graph.forceOverlay' executed in 0.0666s.
# 'comparability_graph.assessEdges' executed in 0.7998s.
# 'comparability_graph.exportCompatFiles' executed in 7.6712s.
# 'comparability_graph.reportCompat' executed in 0.0645s.
#
# TESTING A/P RATIO =  0.2
# 'comparability_graph.reset' executed in 3.6341s.
# 'comparability_graph.findMaintenances' executed in 0.0278s.
# 'comparability_graph.findSplitings' executed in 0.9557s.
# 'comparability_graph.forceOverlay' executed in 5.8358s.
# 'comparability_graph.forceOverlay' executed in 4.6948s.
# 'comparability_graph.forceOverlay' executed in 0.0746s.
# 'comparability_graph.assessEdges' executed in 0.9067s.
# 'comparability_graph.exportCompatFiles' executed in 7.5090s.
# 'comparability_graph.reportCompat' executed in 0.0681s.
#
# TESTING A/P RATIO =  0.3
# 'comparability_graph.reset' executed in 3.6471s.
# 'comparability_graph.findMaintenances' executed in 0.0281s.
# 'comparability_graph.findSplitings' executed in 0.8276s.
# 'comparability_graph.forceOverlay' executed in 5.7921s.
# 'comparability_graph.forceOverlay' executed in 5.2643s.
# 'comparability_graph.forceOverlay' executed in 0.0959s.
# 'comparability_graph.assessEdges' executed in 1.0355s.
# 'comparability_graph.exportCompatFiles' executed in 7.9596s.
# 'comparability_graph.reportCompat' executed in 0.0667s.
#
# TESTING A/P RATIO =  0.4
# 'comparability_graph.reset' executed in 3.6350s.
# 'comparability_graph.findMaintenances' executed in 0.0245s.
# 'comparability_graph.findSplitings' executed in 0.8257s.
# 'comparability_graph.forceOverlay' executed in 5.1281s.
# 'comparability_graph.forceOverlay' executed in 4.7845s.
# 'comparability_graph.forceOverlay' executed in 0.0700s.
# 'comparability_graph.assessEdges' executed in 0.7503s.
# 'comparability_graph.exportCompatFiles' executed in 7.6499s.
# 'comparability_graph.reportCompat' executed in 0.0739s.
#
# TESTING A/P RATIO =  0.5
# 'comparability_graph.reset' executed in 3.8949s.
# 'comparability_graph.findMaintenances' executed in 0.0258s.
# 'comparability_graph.findSplitings' executed in 0.8428s.
# 'comparability_graph.forceOverlay' executed in 5.9353s.
# 'comparability_graph.forceOverlay' executed in 4.5876s.
# 'comparability_graph.forceOverlay' executed in 0.0791s.
# 'comparability_graph.assessEdges' executed in 0.7604s.
# 'comparability_graph.exportCompatFiles' executed in 7.9169s.
# 'comparability_graph.reportCompat' executed in 0.0650s.
#
# TESTING A/P RATIO =  0.6
# 'comparability_graph.reset' executed in 3.6593s.
# 'comparability_graph.findMaintenances' executed in 0.0313s.
# 'comparability_graph.findSplitings' executed in 0.8405s.
# 'comparability_graph.forceOverlay' executed in 5.3999s.
# 'comparability_graph.forceOverlay' executed in 4.6523s.
# 'comparability_graph.forceOverlay' executed in 0.0796s.
# 'comparability_graph.assessEdges' executed in 0.7195s.
# 'comparability_graph.exportCompatFiles' executed in 7.7329s.
# 'comparability_graph.reportCompat' executed in 0.0683s.
#
# TESTING A/P RATIO =  0.7
# 'comparability_graph.reset' executed in 3.5104s.
# 'comparability_graph.findMaintenances' executed in 0.1404s.
# 'comparability_graph.findSplitings' executed in 0.8317s.
# 'comparability_graph.forceOverlay' executed in 5.0587s.
# 'comparability_graph.forceOverlay' executed in 4.4700s.
# 'comparability_graph.forceOverlay' executed in 0.0802s.
# 'comparability_graph.assessEdges' executed in 0.9124s.
# 'comparability_graph.exportCompatFiles' executed in 7.6092s.
# 'comparability_graph.reportCompat' executed in 0.0598s.
#
# TESTING A/P RATIO =  0.8
# 'comparability_graph.reset' executed in 3.5987s.
# 'comparability_graph.findMaintenances' executed in 0.0182s.
# 'comparability_graph.findSplitings' executed in 0.9525s.
# 'comparability_graph.forceOverlay' executed in 5.0175s.
# 'comparability_graph.forceOverlay' executed in 4.4332s.
# 'comparability_graph.forceOverlay' executed in 0.0826s.
# 'comparability_graph.assessEdges' executed in 0.8332s.
# 'comparability_graph.exportCompatFiles' executed in 7.3036s.
# 'comparability_graph.reportCompat' executed in 0.0644s.
#
# TESTING A/P RATIO =  0.9
# 'comparability_graph.reset' executed in 3.5551s.
# 'comparability_graph.findMaintenances' executed in 0.0335s.
# 'comparability_graph.findSplitings' executed in 0.8369s.
# 'comparability_graph.forceOverlay' executed in 5.3092s.
# 'comparability_graph.forceOverlay' executed in 4.5577s.
# 'comparability_graph.forceOverlay' executed in 0.0939s.
# 'comparability_graph.assessEdges' executed in 0.9226s.
# 'comparability_graph.exportCompatFiles' executed in 7.4922s.
# 'comparability_graph.reportCompat' executed in 0.0667s.
#
# TESTING A/P RATIO =  1.0
# 'comparability_graph.reset' executed in 3.6638s.
# 'comparability_graph.findMaintenances' executed in 0.0255s.
# 'comparability_graph.findSplitings' executed in 0.8250s.
# 'comparability_graph.forceOverlay' executed in 5.4281s.
# 'comparability_graph.forceOverlay' executed in 4.6223s.
# 'comparability_graph.forceOverlay' executed in 0.0777s.
# 'comparability_graph.assessEdges' executed in 0.7767s.
# 'comparability_graph.exportCompatFiles' executed in 7.8817s.
# 'comparability_graph.reportCompat' executed in 0.0705s.
#
# TESTING A/P RATIO =  1.1
# 'comparability_graph.reset' executed in 3.5188s.
# 'comparability_graph.findMaintenances' executed in 0.1509s.
# 'comparability_graph.findSplitings' executed in 0.8210s.
# 'comparability_graph.forceOverlay' executed in 5.2582s.
# 'comparability_graph.forceOverlay' executed in 4.5662s.
# 'comparability_graph.forceOverlay' executed in 0.0777s.
# 'comparability_graph.assessEdges' executed in 0.8518s.
# 'comparability_graph.exportCompatFiles' executed in 7.5473s.
# 'comparability_graph.reportCompat' executed in 0.0477s.
#
# TESTING A/P RATIO =  1.2
# 'comparability_graph.reset' executed in 3.6756s.
# 'comparability_graph.findMaintenances' executed in 0.0377s.
# 'comparability_graph.findSplitings' executed in 0.8566s.
# 'comparability_graph.forceOverlay' executed in 5.4862s.
# 'comparability_graph.forceOverlay' executed in 4.6026s.
# 'comparability_graph.forceOverlay' executed in 0.0676s.
# 'comparability_graph.assessEdges' executed in 0.8172s.
# 'comparability_graph.exportCompatFiles' executed in 7.9381s.
# 'comparability_graph.reportCompat' executed in 0.0659s.
#
# TESTING A/P RATIO =  1.3
# 'comparability_graph.reset' executed in 3.6689s.
# 'comparability_graph.findMaintenances' executed in 0.0149s.
# 'comparability_graph.findSplitings' executed in 0.8413s.
# 'comparability_graph.forceOverlay' executed in 5.3511s.
# 'comparability_graph.forceOverlay' executed in 4.6460s.
# 'comparability_graph.forceOverlay' executed in 0.0839s.
# 'comparability_graph.assessEdges' executed in 0.7778s.
# 'comparability_graph.exportCompatFiles' executed in 7.8251s.
# 'comparability_graph.reportCompat' executed in 0.0797s.
#
# TESTING A/P RATIO =  1.4
# 'comparability_graph.reset' executed in 3.7827s.
# 'comparability_graph.findMaintenances' executed in 0.0288s.
# 'comparability_graph.findSplitings' executed in 0.8376s.
# 'comparability_graph.forceOverlay' executed in 5.3419s.
# 'comparability_graph.forceOverlay' executed in 4.6069s.
# 'comparability_graph.forceOverlay' executed in 0.0620s.
# 'comparability_graph.assessEdges' executed in 1.0388s.
# 'comparability_graph.exportCompatFiles' executed in 7.5896s.
# 'comparability_graph.reportCompat' executed in 0.0716s.
#
# TESTING A/P RATIO =  1.5
# 'comparability_graph.reset' executed in 3.7091s.
# 'comparability_graph.findMaintenances' executed in 0.0284s.
# 'comparability_graph.findSplitings' executed in 0.8160s.
# 'comparability_graph.forceOverlay' executed in 5.2344s.
# 'comparability_graph.forceOverlay' executed in 4.5760s.
# 'comparability_graph.forceOverlay' executed in 3.2078s.
# 'comparability_graph.assessEdges' executed in 0.7027s.
# 'comparability_graph.exportCompatFiles' executed in 7.5290s.
# 'comparability_graph.reportCompat' executed in 0.0656s.
#
# TESTING A/P RATIO =  1.6
# 'comparability_graph.reset' executed in 3.5914s.
# 'comparability_graph.findMaintenances' executed in 0.0258s.
# 'comparability_graph.findSplitings' executed in 0.9638s.
# 'comparability_graph.forceOverlay' executed in 5.1119s.
# 'comparability_graph.forceOverlay' executed in 4.4646s.
# 'comparability_graph.forceOverlay' executed in 3.2548s.
# 'comparability_graph.assessEdges' executed in 0.7097s.
# 'comparability_graph.exportCompatFiles' executed in 7.3880s.
# 'comparability_graph.reportCompat' executed in 0.0719s.
#
# TESTING A/P RATIO =  1.7
# 'comparability_graph.reset' executed in 3.6216s.
# 'comparability_graph.findMaintenances' executed in 0.0309s.
# 'comparability_graph.findSplitings' executed in 0.8109s.
# 'comparability_graph.forceOverlay' executed in 5.2264s.
# 'comparability_graph.forceOverlay' executed in 4.4657s.
# 'comparability_graph.forceOverlay' executed in 3.2436s.
# 'comparability_graph.assessEdges' executed in 0.9711s.
# 'comparability_graph.exportCompatFiles' executed in 7.4919s.
# 'comparability_graph.reportCompat' executed in 0.0678s.
#
# TESTING A/P RATIO =  1.8
# 'comparability_graph.reset' executed in 3.6336s.
# 'comparability_graph.findMaintenances' executed in 0.0161s.
# 'comparability_graph.findSplitings' executed in 0.8357s.
# 'comparability_graph.forceOverlay' executed in 5.4274s.
# 'comparability_graph.forceOverlay' executed in 4.5363s.
# 'comparability_graph.forceOverlay' executed in 3.2388s.
# 'comparability_graph.assessEdges' executed in 0.8751s.
# 'comparability_graph.exportCompatFiles' executed in 7.6470s.
# 'comparability_graph.reportCompat' executed in 0.0777s.
#
# TESTING A/P RATIO =  1.9
# 'comparability_graph.reset' executed in 3.7046s.
# 'comparability_graph.findMaintenances' executed in 0.0274s.
# 'comparability_graph.findSplitings' executed in 0.8064s.
# 'comparability_graph.forceOverlay' executed in 5.2710s.
# 'comparability_graph.forceOverlay' executed in 4.6509s.
# 'comparability_graph.forceOverlay' executed in 3.2703s.
# 'comparability_graph.assessEdges' executed in 0.8798s.
# 'comparability_graph.exportCompatFiles' executed in 7.6922s.
# 'comparability_graph.reportCompat' executed in 0.0721s.
#
# TESTING A/P RATIO =  2.0
# 'comparability_graph.reset' executed in 3.6355s.
# 'comparability_graph.findMaintenances' executed in 0.0266s.
# 'comparability_graph.findSplitings' executed in 0.8413s.
# 'comparability_graph.forceOverlay' executed in 5.3870s.
# 'comparability_graph.forceOverlay' executed in 4.4693s.
# 'comparability_graph.forceOverlay' executed in 3.2636s.
# 'comparability_graph.assessEdges' executed in 0.8826s.
# 'comparability_graph.exportCompatFiles' executed in 7.5605s.
# 'comparability_graph.reportCompat' executed in 0.0806s.

# %%
for r in range(1,11):
    lmin = round(0.1 * r,2)

    print('\nTESTING Lmin = ', lmin)
    G_compat.reset()
    G_compat.findMaintenances()
    G_compat.findSplitings(threshold=lmin)
    # Aplica séries de buffers
    for b in [-20, -10]:
        G_compat.forceOverlay(buffer=b)
    # Sobreposição de isolados restantes
    G_compat.forceOverlay(buffer=0, use_all=True)

    G_compat.assessEdges(ground_truth_graph=truth_graph)

    G_compat.exportCompatFiles(BASENAME, NAME_C1, NAME_C2, save_files=False)
    G_compat.reportCompat(file=f'results/params/{BASENAME}_lmin{str(lmin).replace(".",",")}_report')
# Out:
# TESTING Lmin =  0.1
# 'comparability_graph.reset' executed in 3.6774s.
# 'comparability_graph.findMaintenances' executed in 0.0205s.
# 'comparability_graph.findSplitings' executed in 0.8483s.
# 'comparability_graph.forceOverlay' executed in 5.3323s.
# 'comparability_graph.forceOverlay' executed in 4.6839s.
# 'comparability_graph.forceOverlay' executed in 0.0781s.
# 'comparability_graph.assessEdges' executed in 0.7411s.
# 'comparability_graph.exportCompatFiles' executed in 7.8199s.
# 'comparability_graph.reportCompat' executed in 0.0628s.
#
# TESTING Lmin =  0.2
# 'comparability_graph.reset' executed in 3.7036s.
# 'comparability_graph.findMaintenances' executed in 0.0292s.
# 'comparability_graph.findSplitings' executed in 0.8172s.
# 'comparability_graph.forceOverlay' executed in 5.2101s.
# 'comparability_graph.forceOverlay' executed in 4.7368s.
# 'comparability_graph.forceOverlay' executed in 0.0608s.
# 'comparability_graph.assessEdges' executed in 0.8353s.
# 'comparability_graph.exportCompatFiles' executed in 7.8412s.
# 'comparability_graph.reportCompat' executed in 0.0681s.
#
# TESTING Lmin =  0.3
# 'comparability_graph.reset' executed in 3.4760s.
# 'comparability_graph.findMaintenances' executed in 0.0270s.
# 'comparability_graph.findSplitings' executed in 1.0418s.
# 'comparability_graph.forceOverlay' executed in 5.3128s.
# 'comparability_graph.forceOverlay' executed in 4.6619s.
# 'comparability_graph.forceOverlay' executed in 0.0761s.
# 'comparability_graph.assessEdges' executed in 0.8594s.
# 'comparability_graph.exportCompatFiles' executed in 7.7773s.
# 'comparability_graph.reportCompat' executed in 0.0674s.
#
# TESTING Lmin =  0.4
# 'comparability_graph.reset' executed in 3.6759s.
# 'comparability_graph.findMaintenances' executed in 0.0268s.
# 'comparability_graph.findSplitings' executed in 0.9172s.
# 'comparability_graph.forceOverlay' executed in 5.3755s.
# 'comparability_graph.forceOverlay' executed in 4.6805s.
# 'comparability_graph.forceOverlay' executed in 0.0787s.
# 'comparability_graph.assessEdges' executed in 0.7157s.
# 'comparability_graph.exportCompatFiles' executed in 7.8583s.
# 'comparability_graph.reportCompat' executed in 0.0712s.
#
# TESTING Lmin =  0.5
# 'comparability_graph.reset' executed in 3.6291s.
# 'comparability_graph.findMaintenances' executed in 0.0182s.
# 'comparability_graph.findSplitings' executed in 0.8337s.
# 'comparability_graph.forceOverlay' executed in 5.1568s.
# 'comparability_graph.forceOverlay' executed in 4.7956s.
# 'comparability_graph.forceOverlay' executed in 0.0748s.
# 'comparability_graph.assessEdges' executed in 0.7294s.
# 'comparability_graph.exportCompatFiles' executed in 7.7572s.
# 'comparability_graph.reportCompat' executed in 0.0666s.
#
# TESTING Lmin =  0.6
# 'comparability_graph.reset' executed in 3.5508s.
# 'comparability_graph.findMaintenances' executed in 0.0295s.
# 'comparability_graph.findSplitings' executed in 0.8101s.
# 'comparability_graph.forceOverlay' executed in 5.3748s.
# 'comparability_graph.forceOverlay' executed in 4.6982s.
# 'comparability_graph.forceOverlay' executed in 0.0750s.
# 'comparability_graph.assessEdges' executed in 0.8319s.
# 'comparability_graph.exportCompatFiles' executed in 7.8757s.
# 'comparability_graph.reportCompat' executed in 0.0667s.
#
# TESTING Lmin =  0.7
# 'comparability_graph.reset' executed in 3.7593s.
# 'comparability_graph.findMaintenances' executed in 0.0196s.
# 'comparability_graph.findSplitings' executed in 0.8401s.
# 'comparability_graph.forceOverlay' executed in 5.3528s.
# 'comparability_graph.forceOverlay' executed in 4.6072s.
# 'comparability_graph.forceOverlay' executed in 0.0797s.
# 'comparability_graph.assessEdges' executed in 0.7241s.
# 'comparability_graph.exportCompatFiles' executed in 7.7832s.
# 'comparability_graph.reportCompat' executed in 0.0660s.
#
# TESTING Lmin =  0.8
# 'comparability_graph.reset' executed in 3.7155s.
# 'comparability_graph.findMaintenances' executed in 0.0283s.
# 'comparability_graph.findSplitings' executed in 0.8163s.
# 'comparability_graph.forceOverlay' executed in 5.0882s.
# 'comparability_graph.forceOverlay' executed in 4.6618s.
# 'comparability_graph.forceOverlay' executed in 0.0744s.
# 'comparability_graph.assessEdges' executed in 0.7081s.
# 'comparability_graph.exportCompatFiles' executed in 7.6626s.
# 'comparability_graph.reportCompat' executed in 0.0548s.
#
# TESTING Lmin =  0.9
# 'comparability_graph.reset' executed in 3.5351s.
# 'comparability_graph.findMaintenances' executed in 0.0286s.
# 'comparability_graph.findSplitings' executed in 0.8105s.
# 'comparability_graph.forceOverlay' executed in 5.2790s.
# 'comparability_graph.forceOverlay' executed in 4.4448s.
# 'comparability_graph.forceOverlay' executed in 0.0698s.
# 'comparability_graph.assessEdges' executed in 0.7315s.
# 'comparability_graph.exportCompatFiles' executed in 7.6377s.
# 'comparability_graph.reportCompat' executed in 0.0616s.
#
# TESTING Lmin =  1.0
# 'comparability_graph.reset' executed in 3.6499s.
# 'comparability_graph.findMaintenances' executed in 0.0271s.
# 'comparability_graph.findSplitings' executed in 0.8230s.
# 'comparability_graph.forceOverlay' executed in 5.2035s.
# 'comparability_graph.forceOverlay' executed in 4.4491s.
# 'comparability_graph.forceOverlay' executed in 0.0631s.
# 'comparability_graph.assessEdges' executed in 0.6960s.
# 'comparability_graph.exportCompatFiles' executed in 7.6222s.
# 'comparability_graph.reportCompat' executed in 0.0750s.

# %%
df_apr = readMetrics(BASENAME, 'apr')
df_lmin = readMetrics(BASENAME, 'lmin')

# %%
from matplotlib import pyplot as plt
from matplotlib.ticker import MaxNLocator
params = {'mathtext.default': 'regular' , 'font.family':'Roboto'} 
plt.rcParams.update(params)
import seaborn as sns

labels = {
    'Inconsistent maintenance': 'Inconsistent\nmaintenance',
    'Inconsistent splitting':'Inconsistent\nsplitting',
    'Unconnected polygons':'Unconnected\npolygons',
    'Persistent unconnected':'Persistent\nunconnected',
    'Large redesigns':'Large\nredesigns',
    'recall': 'Recall\n(×1000)',
    'precision': 'Precision\n(×1000)',
    'f1_score': 'F1-Score\n(×1000)'
}

fig, ax = plt.subplots(2,len(df_apr.columns)-1,figsize=(15, 4), dpi=150)

for j, c in enumerate([i for i in df_apr.columns if i != 'A/P ratio']):
    i = (0,j)
    group_df = df_apr[['A/P ratio', c]]
    sns.lineplot(x='A/P ratio',y=c, data=group_df, color='blue', ax=ax[i], marker='None')

    # Anotações
    coords = [(x, y) for x,y in zip(group_df['A/P ratio'], group_df[c])]
    t=None
    for coord in coords[::2]:
        if coord[1]!=t:
            t = ax[i].annotate(f'{round(coord[1],0):n}', fontsize=4, xy=coord, textcoords='data', ha='center', va='center', color='white')
            t.set_bbox(dict(facecolor='white', alpha=1, linewidth=0, boxstyle='round,pad=0.8'))
            t = coord[1]
    t=None
    for coord in coords[::2]:
        if coord[1]!=t:
            ax[i].annotate(f'{round(coord[1],0):n}', fontsize=7, color='blue', xy=coord, textcoords='data', ha='center', va='center',zorder=5, fontweight='medium')
            t = coord[1]

    ax[i].set_title(labels[c], fontsize=13, ha='left', x=0)
    ax[i].xaxis.set_label_text('')

    ax[i].xaxis.set_ticks(group_df['A/P ratio'].to_list()[::2])
    ax[i].tick_params(axis='x', color='white', labelcolor='black', labelsize=9, rotation=90, pad=-2)

    [t.set_color('#aaaaaa') for t in ax[i].yaxis.get_ticklabels()]
    [t.set_va('bottom') for t in ax[i].yaxis.get_ticklabels()]
    ax[i].yaxis.set_major_locator(MaxNLocator(integer=True))
    ax[i].yaxis.set_ticklabels([t for t in ax[i].yaxis.get_ticklabels()])
    #ax[i].xaxis.set_ticklabels([])
    ax[i].yaxis.set_ticklabels([])
    ax[i].yaxis.set_label_text('')
    ax[i].tick_params(axis='y', color='white')

    if j==0:
        ax[i].set_ylabel('A/P', loc='top', va='top', fontsize=12, fontweight='medium')
        #ax[i].yaxis.set_label_text(r'A/P')
        ax[i].yaxis.label.set_color('blue')
        ax[i].yaxis.label.set_rotation(0)

    ax[i].grid(axis='y', visible=True, color='#eeeeee')
    ax[i].grid(axis='x', visible=True, color='#eeeeee')
    ax[i].set_facecolor("white")

for j, c in enumerate([i for i in df_lmin.columns if i != 'Lmin']):
    i = (1,j)
    group_df = df_lmin[['Lmin', c]]
    sns.lineplot(x='Lmin',y=c, data=group_df, color='deeppink', ax=ax[i], marker='None')

    # Anotações
    coords = [(x, y) for x,y in zip(group_df['Lmin'], group_df[c])]
    t=None
    for coord in coords:
        if coord[1]!=t:
            t = ax[i].annotate(f'{round(coord[1],0):n}', fontsize=4, xy=coord, textcoords='data', ha='center', va='center', color='white')
            t.set_bbox(dict(facecolor='white', alpha=1, linewidth=0, boxstyle='round,pad=0.8'))
            t = coord[1]
    t=None
    for coord in coords:
        if coord[1]!=t:
            ax[i].annotate(f'{round(coord[1],0):n}', fontsize=7, color='deeppink', xy=coord, textcoords='data', ha='center', va='center',zorder=5, fontweight='medium')
            t = coord[1]

    #ax[i].set_title(c.replace(' ','\n').replace('nao\npuras','nao puras'), ha='left', x=0)
    ax[i].xaxis.set_label_text('')

    ax[i].xaxis.set_ticks(group_df['Lmin'].to_list())
    ax[i].tick_params(axis='x', color='white', labelcolor='black', labelsize=9, rotation=90, pad=-2)

    [t.set_color('#aaaaaa') for t in ax[i].yaxis.get_ticklabels()]
    [t.set_va('bottom') for t in ax[i].yaxis.get_ticklabels()]
    ax[i].yaxis.set_major_locator(MaxNLocator(integer=True))
    ax[i].yaxis.set_ticklabels([t for t in ax[i].yaxis.get_ticklabels()])
    #ax[i].xaxis.set_ticklabels([])
    ax[i].yaxis.set_ticklabels([])
    ax[i].yaxis.set_label_text('')
    ax[i].tick_params(axis='y', color='white')

    if j==0:
        ax[i].set_ylabel('$L_{min}$', loc='top', va='top', fontsize=12, fontweight='medium')
        #ax[i].yaxis.set_label_text('$L_{min}$')
        ax[i].yaxis.label.set_color('deeppink')
        ax[i].yaxis.label.set_rotation(0)

    ax[i].grid(axis='y', visible=True, color='#eeeeee')
    ax[i].grid(axis='x', visible=True, color='#eeeeee')
    ax[i].set_facecolor("white")

fig.tight_layout()
plt.savefig(f'docs/analise_params_{location}.png', bbox_inches='tight')
plt.show()
