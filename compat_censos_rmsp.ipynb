# %% [markdown]
# # Comparability for 2010-2022 Census Tracts in São Paulo Metropolitan Region (RMSP)

# %%
from utils import *

# %%
C1 = '2010'
C2 = '2022'
location = 'RMSP'

BASENAME = f'{C1}_{C2}_{location}' # Nome da compatibilização
NAME_C1 = f'{location}_{C1}' # Nome da primeira malha censitária
NAME_C2 = f'{location}_{C2}' # Nome da segunda malha censitária

# %% [markdown]
# ## 1. Census layers pre-processing
# The following cell pre-processes the census layers and only needs to run once

# %% [raw]
# # RMSP municipal codes
# muns = ['3503901', '3505708', '3506607', '3509007', '3509205', '3510609', '3513009', '3513801', '3515004',
#         '3515103', '3515707', '3516309', '3516408', '3518305', '3518800', '3522208', '3522505', '3523107',
#         '3525003', '3526209', '3528502', '3529401', '3530607', '3534401', '3539103', '3539806', '3543303',
#         '3544103', '3545001', '3546801', '3547304', '3547809', '3548708', '3548807', '3549953', '3550308',
#         '3552502', '3552809', '3556453']
#
# # Census layer creation
# layer_2010 = makeCensusLayer('resources/ibge/Setores IBGE.gpkg',
#                             id_column='CD_GEOCODI',
#                             layer='SP_2010',
#                             filter=muns,
#                             geosys='SIRGAS2000')
# layer_2022 = makeCensusLayer('resources/ibge/Setores IBGE.gpkg',
#                             id_column='CD_SETOR',
#                             layer='SP_2022P',
#                             filter=muns,
#                             geosys='SIRGAS2000')
#
# # Exporting
# layer_2010.to_parquet(f'results/{NAME_C1}.parquet')
# layer_2022.to_parquet(f'results/{NAME_C2}.parquet')

# %%
# Importing
layer_2010 = gpd.read_parquet(f'results/{NAME_C1}.parquet')
layer_2022 = gpd.read_parquet(f'results/{NAME_C2}.parquet')

# %% [markdown]
# ## 2. Comparability graph

# %%
G_compat = comparability_graph(layer_2010, layer_2022)
# Out:
# 'comparability_graph.makeGridUnion' executed in 133.9004s.
# 'getNeighborhoods' executed in 0.0565s.
# 'getNeighborhoods' executed in 0.1101s.
# 'comparability_graph.classifyGridChanges' executed in 17.7098s.
# 'comparability_graph.__init__' executed in 156.9832s.

# %%
G_compat.findMaintenances()
G_compat.findSplitings(threshold=0.8)

# Aplica séries de buffers
for b in [-20, -10]:
    G_compat.forceOverlay(buffer=b)

# Sobreposição de isolados restantes
G_compat.forceOverlay(buffer=0, use_all=True)
# Out:
# 'comparability_graph.findMaintenances' executed in 0.0414s.
# 'comparability_graph.findSplitings' executed in 1.2221s.
# 'comparability_graph.forceOverlay' executed in 19.9832s.
# 'comparability_graph.forceOverlay' executed in 10.8239s.
# 'comparability_graph.forceOverlay' executed in 11.3555s.

# %% [markdown]
# ## 3. Assessing gold standard

# %%
# Import gold standard relationship file
df_comp_ibge = pd.read_excel('resources/ibge/Historico_formacao_Setores_Censitarios_2010_2022.xlsx')

nodesA = [int(i[2:]) for i in G_compat.nodes() if i.startswith('A')]
nodesB = [int(i[2:]) for i in G_compat.nodes() if i.startswith('B')]
ibge_2010_2022 = df_comp_ibge[['GEOCODIGO_2022_PRELIMINAR','GEOCODIGO_2010']]
ibge_2010_2022 = ibge_2010_2022.query('GEOCODIGO_2022_PRELIMINAR in @nodesB | GEOCODIGO_2010 in @nodesA')

truth_graph = nx.Graph()

# Add existing nodes
truth_graph.add_nodes_from(G_compat.nodes())

# Add gold standard edges
for _, r in ibge_2010_2022.iterrows():
    truth_graph.add_edge(f"A.{r['GEOCODIGO_2010']}", f"B.{r['GEOCODIGO_2022_PRELIMINAR']}")

# Remove exceding nodes
exceeding_nodes = [i for i in truth_graph.nodes() if i not in G_compat.nodes()]
truth_graph.remove_nodes_from(exceeding_nodes)

# %%
G_compat.assessEdges(ground_truth_graph=truth_graph)
# Out:
# 'comparability_graph.assessEdges' executed in 1.3108s.

# %% [markdown]
# ## 4. Export results

# %%
G_compat.exportCompatFiles(BASENAME, NAME_C1, NAME_C2)
G_compat.reportCompat(file=f'results/{BASENAME}_report')
# Out:
# 'comparability_graph.exportCompatFiles' executed in 16.1546s.
# 'comparability_graph.reportCompat' executed in 0.1095s.
# {'params': {'A/P ratio': 0.3,
#   'Lmin': [0.8],
#   'Buffers': [{'buffer': -20, 'use_all': False},
#    {'buffer': -10, 'use_all': False},
#    {'buffer': 0, 'use_all': True}]},
#  'layers': {'Setores C1': 30815, 'Setores C2': 47184},
#  'relationships': {'Total relationships': {'n': 52115, 'pct': 1},
#   '': {'n': 1430, 'pct': 0.02743931689532764},
#   'Divisão': {'n': 22600, 'pct': 0.4336563369471361},
#   'Manutenção': {'n': 18128, 'pct': 0.34784610956538425},
#   'Manutenção desassociada': {'n': 6, 'pct': 0.00011513000095941667},
#   'Sobreposição (-10m)': {'n': 2271, 'pct': 0.04357670536313921},
#   'Sobreposição (-20m)': {'n': 7116, 'pct': 0.13654418113786818},
#   'Sobreposição (0m)': {'n': 564, 'pct': 0.010822220090185167}},
#  'operations': {'Total redesign operations': {'n': 27990, 'pct': 1},
#   '1:1': {'n': 18733, 'pct': 0.669274740978921},
#   '1:n': {'n': 7898, 'pct': 0.28217220435869955},
#   'm:n': {'n': 1216, 'pct': 0.04344408717399071},
#   'n:1': {'n': 143, 'pct': 0.00510896748838871}},
#  'metrics': {'Inconsistent maintenance': {'n': 140,
#    'pct': 0.003861429832303619},
#   'Inconsistent splitting': {'n': 4559.0, 'pct': 0.20172566371681416},
#   'Unconnected polygons': {'n': 2, 'pct': 2.5641354376338157e-05},
#   'Persistent unconnected': {'n': 564, 'pct': 0.00723086193412736},
#   'Large redesigns': {'n': 26, 'pct': 0.0009289031797070382}},
#  'assessment': {'true positives': 46173,
#   'false positives': 4512,
#   'false negatives': 1430,
#   'recall': 0.9699598764783732,
#   'precision': 0.9109795797573247,
#   'f1_score': 0.9395450105811493}}

# %% [markdown]
# ## 5. Parameter refinement test

# %%
for r in range(1,21):
    apr = round(0.1*r,2)
    print('\nTESTING A/P RATIO = ', apr)
    G_compat.reset(ap_ratio=apr)
    G_compat.findMaintenances()
    G_compat.findSplitings(threshold=0.8)
    # Aplica séries de buffers
    for b in [-20, -10]:
        G_compat.forceOverlay(buffer=b)
    # Sobreposição de isolados restantes
    G_compat.forceOverlay(buffer=0, use_all=True)

    G_compat.assessEdges(ground_truth_graph=truth_graph)

    G_compat.exportCompatFiles(BASENAME, NAME_C1, NAME_C2, save_files=False)
    G_compat.reportCompat(file=f'results/params/{BASENAME}_apr{str(apr).replace(".",",")}_report')
# Out:
# TESTING A/P RATIO =  0.1
# 'comparability_graph.reset' executed in 5.5040s.
# 'comparability_graph.findMaintenances' executed in 0.0419s.
# 'comparability_graph.findSplitings' executed in 1.1757s.
# 'comparability_graph.forceOverlay' executed in 20.1521s.
# 'comparability_graph.forceOverlay' executed in 10.7089s.
# 'comparability_graph.forceOverlay' executed in 11.3709s.
# 'comparability_graph.assessEdges' executed in 1.4857s.
# 'comparability_graph.exportCompatFiles' executed in 13.2032s.
# 'comparability_graph.reportCompat' executed in 0.1167s.
#
# TESTING A/P RATIO =  0.2
# 'comparability_graph.reset' executed in 5.3241s.
# 'comparability_graph.findMaintenances' executed in 0.0506s.
# 'comparability_graph.findSplitings' executed in 1.2884s.
# 'comparability_graph.forceOverlay' executed in 19.8513s.
# 'comparability_graph.forceOverlay' executed in 10.7439s.
# 'comparability_graph.forceOverlay' executed in 11.1058s.
# 'comparability_graph.assessEdges' executed in 1.4716s.
# 'comparability_graph.exportCompatFiles' executed in 13.1829s.
# 'comparability_graph.reportCompat' executed in 0.1043s.
#
# TESTING A/P RATIO =  0.3
# 'comparability_graph.reset' executed in 5.2937s.
# 'comparability_graph.findMaintenances' executed in 0.0427s.
# 'comparability_graph.findSplitings' executed in 1.2927s.
# 'comparability_graph.forceOverlay' executed in 19.8432s.
# 'comparability_graph.forceOverlay' executed in 10.8285s.
# 'comparability_graph.forceOverlay' executed in 11.7494s.
# 'comparability_graph.assessEdges' executed in 1.3294s.
# 'comparability_graph.exportCompatFiles' executed in 13.2146s.
# 'comparability_graph.reportCompat' executed in 0.1095s.
#
# TESTING A/P RATIO =  0.4
# 'comparability_graph.reset' executed in 5.4723s.
# 'comparability_graph.findMaintenances' executed in 0.0497s.
# 'comparability_graph.findSplitings' executed in 1.1559s.
# 'comparability_graph.forceOverlay' executed in 20.0458s.
# 'comparability_graph.forceOverlay' executed in 10.6620s.
# 'comparability_graph.forceOverlay' executed in 11.2525s.
# 'comparability_graph.assessEdges' executed in 1.4828s.
# 'comparability_graph.exportCompatFiles' executed in 12.9342s.
# 'comparability_graph.reportCompat' executed in 0.1042s.
#
# TESTING A/P RATIO =  0.5
# 'comparability_graph.reset' executed in 5.4331s.
# 'comparability_graph.findMaintenances' executed in 0.1664s.
# 'comparability_graph.findSplitings' executed in 1.1490s.
# 'comparability_graph.forceOverlay' executed in 19.8964s.
# 'comparability_graph.forceOverlay' executed in 10.9184s.
# 'comparability_graph.forceOverlay' executed in 11.3177s.
# 'comparability_graph.assessEdges' executed in 1.2659s.
# 'comparability_graph.exportCompatFiles' executed in 13.1450s.
# 'comparability_graph.reportCompat' executed in 0.1194s.
#
# TESTING A/P RATIO =  0.6
# 'comparability_graph.reset' executed in 5.5859s.
# 'comparability_graph.findMaintenances' executed in 0.0414s.
# 'comparability_graph.findSplitings' executed in 1.1694s.
# 'comparability_graph.forceOverlay' executed in 20.2386s.
# 'comparability_graph.forceOverlay' executed in 10.7055s.
# 'comparability_graph.forceOverlay' executed in 11.5062s.
# 'comparability_graph.assessEdges' executed in 1.2643s.
# 'comparability_graph.exportCompatFiles' executed in 13.1888s.
# 'comparability_graph.reportCompat' executed in 0.1096s.
#
# TESTING A/P RATIO =  0.7
# 'comparability_graph.reset' executed in 5.3868s.
# 'comparability_graph.findMaintenances' executed in 0.1690s.
# 'comparability_graph.findSplitings' executed in 1.1501s.
# 'comparability_graph.forceOverlay' executed in 19.8365s.
# 'comparability_graph.forceOverlay' executed in 11.0380s.
# 'comparability_graph.forceOverlay' executed in 11.3681s.
# 'comparability_graph.assessEdges' executed in 1.2647s.
# 'comparability_graph.exportCompatFiles' executed in 13.0182s.
# 'comparability_graph.reportCompat' executed in 0.1552s.
#
# TESTING A/P RATIO =  0.8
# 'comparability_graph.reset' executed in 5.4651s.
# 'comparability_graph.findMaintenances' executed in 0.0455s.
# 'comparability_graph.findSplitings' executed in 1.1351s.
# 'comparability_graph.forceOverlay' executed in 19.8538s.
# 'comparability_graph.forceOverlay' executed in 11.0476s.
# 'comparability_graph.forceOverlay' executed in 11.4144s.
# 'comparability_graph.assessEdges' executed in 1.5034s.
# 'comparability_graph.exportCompatFiles' executed in 12.8580s.
# 'comparability_graph.reportCompat' executed in 0.1140s.
#
# TESTING A/P RATIO =  0.9
# 'comparability_graph.reset' executed in 5.5154s.
# 'comparability_graph.findMaintenances' executed in 0.0335s.
# 'comparability_graph.findSplitings' executed in 1.3338s.
# 'comparability_graph.forceOverlay' executed in 19.9312s.
# 'comparability_graph.forceOverlay' executed in 10.9419s.
# 'comparability_graph.forceOverlay' executed in 11.3038s.
# 'comparability_graph.assessEdges' executed in 1.2445s.
# 'comparability_graph.exportCompatFiles' executed in 13.0163s.
# 'comparability_graph.reportCompat' executed in 0.1093s.
#
# TESTING A/P RATIO =  1.0
# 'comparability_graph.reset' executed in 5.5062s.
# 'comparability_graph.findMaintenances' executed in 0.0520s.
# 'comparability_graph.findSplitings' executed in 1.1463s.
# 'comparability_graph.forceOverlay' executed in 19.9301s.
# 'comparability_graph.forceOverlay' executed in 10.9270s.
# 'comparability_graph.forceOverlay' executed in 11.5073s.
# 'comparability_graph.assessEdges' executed in 1.3065s.
# 'comparability_graph.exportCompatFiles' executed in 13.2918s.
# 'comparability_graph.reportCompat' executed in 0.1340s.
#
# TESTING A/P RATIO =  1.1
# 'comparability_graph.reset' executed in 5.6043s.
# 'comparability_graph.findMaintenances' executed in 0.1585s.
# 'comparability_graph.findSplitings' executed in 1.1908s.
# 'comparability_graph.forceOverlay' executed in 20.1785s.
# 'comparability_graph.forceOverlay' executed in 10.8613s.
# 'comparability_graph.forceOverlay' executed in 11.4625s.
# 'comparability_graph.assessEdges' executed in 1.4487s.
# 'comparability_graph.exportCompatFiles' executed in 13.1058s.
# 'comparability_graph.reportCompat' executed in 0.1041s.
#
# TESTING A/P RATIO =  1.2
# 'comparability_graph.reset' executed in 5.4548s.
# 'comparability_graph.findMaintenances' executed in 0.0504s.
# 'comparability_graph.findSplitings' executed in 1.1430s.
# 'comparability_graph.forceOverlay' executed in 20.0150s.
# 'comparability_graph.forceOverlay' executed in 11.0960s.
# 'comparability_graph.forceOverlay' executed in 11.4780s.
# 'comparability_graph.assessEdges' executed in 1.2526s.
# 'comparability_graph.exportCompatFiles' executed in 13.3202s.
# 'comparability_graph.reportCompat' executed in 0.1194s.
#
# TESTING A/P RATIO =  1.3
# 'comparability_graph.reset' executed in 5.5995s.
# 'comparability_graph.findMaintenances' executed in 0.0559s.
# 'comparability_graph.findSplitings' executed in 1.1711s.
# 'comparability_graph.forceOverlay' executed in 20.1291s.
# 'comparability_graph.forceOverlay' executed in 11.0817s.
# 'comparability_graph.forceOverlay' executed in 11.5881s.
# 'comparability_graph.assessEdges' executed in 1.4745s.
# 'comparability_graph.exportCompatFiles' executed in 13.2052s.
# 'comparability_graph.reportCompat' executed in 0.1090s.
#
# TESTING A/P RATIO =  1.4
# 'comparability_graph.reset' executed in 5.4404s.
# 'comparability_graph.findMaintenances' executed in 0.0358s.
# 'comparability_graph.findSplitings' executed in 1.1533s.
# 'comparability_graph.forceOverlay' executed in 19.7646s.
# 'comparability_graph.forceOverlay' executed in 11.1931s.
# 'comparability_graph.forceOverlay' executed in 11.4133s.
# 'comparability_graph.assessEdges' executed in 1.2384s.
# 'comparability_graph.exportCompatFiles' executed in 13.2848s.
# 'comparability_graph.reportCompat' executed in 0.1055s.
#
# TESTING A/P RATIO =  1.5
# 'comparability_graph.reset' executed in 5.4543s.
# 'comparability_graph.findMaintenances' executed in 0.0312s.
# 'comparability_graph.findSplitings' executed in 1.1505s.
# 'comparability_graph.forceOverlay' executed in 19.7739s.
# 'comparability_graph.forceOverlay' executed in 11.2724s.
# 'comparability_graph.forceOverlay' executed in 11.6199s.
# 'comparability_graph.assessEdges' executed in 1.2823s.
# 'comparability_graph.exportCompatFiles' executed in 13.1616s.
# 'comparability_graph.reportCompat' executed in 0.1152s.
#
# TESTING A/P RATIO =  1.6
# 'comparability_graph.reset' executed in 5.5598s.
# 'comparability_graph.findMaintenances' executed in 0.0470s.
# 'comparability_graph.findSplitings' executed in 1.1526s.
# 'comparability_graph.forceOverlay' executed in 20.0623s.
# 'comparability_graph.forceOverlay' executed in 11.2434s.
# 'comparability_graph.forceOverlay' executed in 11.6788s.
# 'comparability_graph.assessEdges' executed in 1.4658s.
# 'comparability_graph.exportCompatFiles' executed in 12.8358s.
# 'comparability_graph.reportCompat' executed in 0.1038s.
#
# TESTING A/P RATIO =  1.7
# 'comparability_graph.reset' executed in 5.3551s.
# 'comparability_graph.findMaintenances' executed in 0.1669s.
# 'comparability_graph.findSplitings' executed in 1.1206s.
# 'comparability_graph.forceOverlay' executed in 19.5369s.
# 'comparability_graph.forceOverlay' executed in 11.0545s.
# 'comparability_graph.forceOverlay' executed in 11.4088s.
# 'comparability_graph.assessEdges' executed in 1.2291s.
# 'comparability_graph.exportCompatFiles' executed in 12.9654s.
# 'comparability_graph.reportCompat' executed in 0.1066s.
#
# TESTING A/P RATIO =  1.8
# 'comparability_graph.reset' executed in 5.3951s.
# 'comparability_graph.findMaintenances' executed in 0.0362s.
# 'comparability_graph.findSplitings' executed in 1.1368s.
# 'comparability_graph.forceOverlay' executed in 19.6514s.
# 'comparability_graph.forceOverlay' executed in 11.0071s.
# 'comparability_graph.forceOverlay' executed in 11.4689s.
# 'comparability_graph.assessEdges' executed in 1.2225s.
# 'comparability_graph.exportCompatFiles' executed in 12.9170s.
# 'comparability_graph.reportCompat' executed in 0.1038s.
#
# TESTING A/P RATIO =  1.9
# 'comparability_graph.reset' executed in 5.4068s.
# 'comparability_graph.findMaintenances' executed in 0.0422s.
# 'comparability_graph.findSplitings' executed in 1.2628s.
# 'comparability_graph.forceOverlay' executed in 19.5653s.
# 'comparability_graph.forceOverlay' executed in 11.1937s.
# 'comparability_graph.forceOverlay' executed in 11.5283s.
# 'comparability_graph.assessEdges' executed in 1.2543s.
# 'comparability_graph.exportCompatFiles' executed in 12.9343s.
# 'comparability_graph.reportCompat' executed in 0.1187s.
#
# TESTING A/P RATIO =  2.0
# 'comparability_graph.reset' executed in 5.4616s.
# 'comparability_graph.findMaintenances' executed in 0.0439s.
# 'comparability_graph.findSplitings' executed in 1.1452s.
# 'comparability_graph.forceOverlay' executed in 19.9533s.
# 'comparability_graph.forceOverlay' executed in 11.4584s.
# 'comparability_graph.forceOverlay' executed in 11.5710s.
# 'comparability_graph.assessEdges' executed in 1.5269s.
# 'comparability_graph.exportCompatFiles' executed in 13.0882s.
# 'comparability_graph.reportCompat' executed in 0.1056s.

# %%
for r in range(1,11):
    lmin = round(0.1 * r,2)

    print('\nTESTING Lmin = ', lmin)
    G_compat.reset()
    G_compat.findMaintenances()
    G_compat.findSplitings(threshold=lmin)
    # Aplica séries de buffers
    for b in [-20, -10]:
        G_compat.forceOverlay(buffer=b)
    # Sobreposição de isolados restantes
    G_compat.forceOverlay(buffer=0, use_all=True)

    G_compat.assessEdges(ground_truth_graph=truth_graph)

    G_compat.exportCompatFiles(BASENAME, NAME_C1, NAME_C2, save_files=False)
    G_compat.reportCompat(file=f'results/params/{BASENAME}_lmin{str(lmin).replace(".",",")}_report.json')
# Out:
# TESTING Lmin =  0.1
# 'comparability_graph.reset' executed in 5.7554s.
# 'comparability_graph.findMaintenances' executed in 0.0465s.
# 'comparability_graph.findSplitings' executed in 1.5029s.
# 'comparability_graph.forceOverlay' executed in 13.1056s.
# 'comparability_graph.forceOverlay' executed in 9.6168s.
# 'comparability_graph.forceOverlay' executed in 10.9259s.
# 'comparability_graph.assessEdges' executed in 1.2897s.
# 'comparability_graph.exportCompatFiles' executed in 13.0248s.
# 'comparability_graph.reportCompat' executed in 0.1069s.
#
# TESTING Lmin =  0.2
# 'comparability_graph.reset' executed in 5.2845s.
# 'comparability_graph.findMaintenances' executed in 0.1866s.
# 'comparability_graph.findSplitings' executed in 1.3815s.
# 'comparability_graph.forceOverlay' executed in 13.2928s.
# 'comparability_graph.forceOverlay' executed in 9.8482s.
# 'comparability_graph.forceOverlay' executed in 10.7486s.
# 'comparability_graph.assessEdges' executed in 1.4206s.
# 'comparability_graph.exportCompatFiles' executed in 12.7903s.
# 'comparability_graph.reportCompat' executed in 0.1069s.
#
# TESTING Lmin =  0.3
# 'comparability_graph.reset' executed in 5.5321s.
# 'comparability_graph.findMaintenances' executed in 0.1984s.
# 'comparability_graph.findSplitings' executed in 1.3341s.
# 'comparability_graph.forceOverlay' executed in 13.7031s.
# 'comparability_graph.forceOverlay' executed in 9.8310s.
# 'comparability_graph.forceOverlay' executed in 10.8148s.
# 'comparability_graph.assessEdges' executed in 1.4093s.
# 'comparability_graph.exportCompatFiles' executed in 12.8009s.
# 'comparability_graph.reportCompat' executed in 0.1207s.
#
# TESTING Lmin =  0.4
# 'comparability_graph.reset' executed in 5.7140s.
# 'comparability_graph.findMaintenances' executed in 0.0490s.
# 'comparability_graph.findSplitings' executed in 1.4599s.
# 'comparability_graph.forceOverlay' executed in 14.5065s.
# 'comparability_graph.forceOverlay' executed in 10.2378s.
# 'comparability_graph.forceOverlay' executed in 11.0049s.
# 'comparability_graph.assessEdges' executed in 1.4970s.
# 'comparability_graph.exportCompatFiles' executed in 13.0729s.
# 'comparability_graph.reportCompat' executed in 0.1061s.
#
# TESTING Lmin =  0.5
# 'comparability_graph.reset' executed in 5.3112s.
# 'comparability_graph.findMaintenances' executed in 0.0522s.
# 'comparability_graph.findSplitings' executed in 1.2857s.
# 'comparability_graph.forceOverlay' executed in 15.8395s.
# 'comparability_graph.forceOverlay' executed in 10.2725s.
# 'comparability_graph.forceOverlay' executed in 11.3058s.
# 'comparability_graph.assessEdges' executed in 1.2806s.
# 'comparability_graph.exportCompatFiles' executed in 13.0375s.
# 'comparability_graph.reportCompat' executed in 0.1093s.
#
# TESTING Lmin =  0.6
# 'comparability_graph.reset' executed in 5.5849s.
# 'comparability_graph.findMaintenances' executed in 0.0443s.
# 'comparability_graph.findSplitings' executed in 1.2779s.
# 'comparability_graph.forceOverlay' executed in 16.9904s.
# 'comparability_graph.forceOverlay' executed in 10.4650s.
# 'comparability_graph.forceOverlay' executed in 11.2025s.
# 'comparability_graph.assessEdges' executed in 1.4736s.
# 'comparability_graph.exportCompatFiles' executed in 12.9249s.
# 'comparability_graph.reportCompat' executed in 0.1081s.
#
# TESTING Lmin =  0.7
# 'comparability_graph.reset' executed in 5.4852s.
# 'comparability_graph.findMaintenances' executed in 0.1824s.
# 'comparability_graph.findSplitings' executed in 1.2103s.
# 'comparability_graph.forceOverlay' executed in 17.6139s.
# 'comparability_graph.forceOverlay' executed in 10.7182s.
# 'comparability_graph.forceOverlay' executed in 11.0788s.
# 'comparability_graph.assessEdges' executed in 1.4307s.
# 'comparability_graph.exportCompatFiles' executed in 13.1608s.
# 'comparability_graph.reportCompat' executed in 0.1089s.
#
# TESTING Lmin =  0.8
# 'comparability_graph.reset' executed in 5.3163s.
# 'comparability_graph.findMaintenances' executed in 0.1863s.
# 'comparability_graph.findSplitings' executed in 1.1472s.
# 'comparability_graph.forceOverlay' executed in 19.7947s.
# 'comparability_graph.forceOverlay' executed in 10.8848s.
# 'comparability_graph.forceOverlay' executed in 11.2586s.
# 'comparability_graph.assessEdges' executed in 1.4612s.
# 'comparability_graph.exportCompatFiles' executed in 13.2487s.
# 'comparability_graph.reportCompat' executed in 0.1086s.
#
# TESTING Lmin =  0.9
# 'comparability_graph.reset' executed in 5.3859s.
# 'comparability_graph.findMaintenances' executed in 0.0614s.
# 'comparability_graph.findSplitings' executed in 1.2030s.
# 'comparability_graph.forceOverlay' executed in 24.2213s.
# 'comparability_graph.forceOverlay' executed in 11.0979s.
# 'comparability_graph.forceOverlay' executed in 11.1817s.
# 'comparability_graph.assessEdges' executed in 1.4823s.
# 'comparability_graph.exportCompatFiles' executed in 13.4627s.
# 'comparability_graph.reportCompat' executed in 0.1103s.
#
# TESTING Lmin =  1.0
# 'comparability_graph.reset' executed in 5.3510s.
# 'comparability_graph.findMaintenances' executed in 0.0503s.
# 'comparability_graph.findSplitings' executed in 0.4896s.
# 'comparability_graph.forceOverlay' executed in 55.4808s.
# 'comparability_graph.forceOverlay' executed in 11.3014s.
# 'comparability_graph.forceOverlay' executed in 11.1398s.
# 'comparability_graph.assessEdges' executed in 1.5006s.
# 'comparability_graph.exportCompatFiles' executed in 13.7875s.
# 'comparability_graph.reportCompat' executed in 0.1115s.

# %%
df_apr = readMetrics(BASENAME, 'apr')
df_lmin = readMetrics(BASENAME, 'lmin')

# %%
from matplotlib import pyplot as plt
from matplotlib.ticker import MaxNLocator
params = {'mathtext.default': 'regular' , 'font.family':'Roboto'} 
plt.rcParams.update(params)
import seaborn as sns

labels = {
    'Inconsistent maintenance': 'Inconsistent\nmaintenance',
    'Inconsistent splitting':'Inconsistent\nsplitting',
    'Unconnected polygons':'Unconnected\npolygons',
    'Persistent unconnected':'Persistent\nunconnected',
    'Large redesigns':'Large\nredesigns',
    'recall': 'Recall\n(×1000)',
    'precision': 'Precision\n(×1000)',
    'f1_score': 'F1-Score\n(×1000)'
}

fig, ax = plt.subplots(2,len(df_apr.columns)-1,figsize=(15, 4), dpi=150)

for j, c in enumerate([i for i in df_apr.columns if i != 'A/P ratio']):
    i = (0,j)
    group_df = df_apr[['A/P ratio', c]]
    sns.lineplot(x='A/P ratio',y=c, data=group_df, color='blue', ax=ax[i], marker='None')

    # Anotações
    coords = [(x, y) for x,y in zip(group_df['A/P ratio'], group_df[c])]
    t=None
    for coord in coords[::2]:
        if coord[1]!=t:
            t = ax[i].annotate(f'{round(coord[1],0):n}', fontsize=4, xy=coord, textcoords='data', ha='center', va='center', color='white')
            t.set_bbox(dict(facecolor='white', alpha=1, linewidth=0, boxstyle='round,pad=0.8'))
            t = coord[1]
    t=None
    for coord in coords[::2]:
        if coord[1]!=t:
            ax[i].annotate(f'{round(coord[1],0):n}', fontsize=7, color='blue', xy=coord, textcoords='data', ha='center', va='center',zorder=5, fontweight='medium')
            t = coord[1]

    ax[i].set_title(labels[c], fontsize=13, ha='left', x=0)
    ax[i].xaxis.set_label_text('')

    ax[i].xaxis.set_ticks(group_df['A/P ratio'].to_list()[::2])
    ax[i].tick_params(axis='x', color='white', labelcolor='black', labelsize=9, rotation=90, pad=-2)

    [t.set_color('#aaaaaa') for t in ax[i].yaxis.get_ticklabels()]
    [t.set_va('bottom') for t in ax[i].yaxis.get_ticklabels()]
    ax[i].yaxis.set_major_locator(MaxNLocator(integer=True))
    ax[i].yaxis.set_ticklabels([t for t in ax[i].yaxis.get_ticklabels()])
    #ax[i].xaxis.set_ticklabels([])
    ax[i].yaxis.set_ticklabels([])
    ax[i].yaxis.set_label_text('')
    ax[i].tick_params(axis='y', color='white')

    if j==0:
        ax[i].set_ylabel('A/P', loc='top', va='top', fontsize=12, fontweight='medium')
        #ax[i].yaxis.set_label_text(r'A/P')
        ax[i].yaxis.label.set_color('blue')
        ax[i].yaxis.label.set_rotation(0)

    ax[i].grid(axis='y', visible=True, color='#eeeeee')
    ax[i].grid(axis='x', visible=True, color='#eeeeee')
    ax[i].set_facecolor("white")

for j, c in enumerate([i for i in df_lmin.columns if i != 'Lmin']):
    i = (1,j)
    group_df = df_lmin[['Lmin', c]]
    sns.lineplot(x='Lmin',y=c, data=group_df, color='deeppink', ax=ax[i], marker='None')

    # Anotações
    coords = [(x, y) for x,y in zip(group_df['Lmin'], group_df[c])]
    t=None
    for coord in coords:
        if coord[1]!=t:
            t = ax[i].annotate(f'{round(coord[1],0):n}', fontsize=4, xy=coord, textcoords='data', ha='center', va='center', color='white')
            t.set_bbox(dict(facecolor='white', alpha=1, linewidth=0, boxstyle='round,pad=0.8'))
            t = coord[1]
    t=None
    for coord in coords:
        if coord[1]!=t:
            ax[i].annotate(f'{round(coord[1],0):n}', fontsize=7, color='deeppink', xy=coord, textcoords='data', ha='center', va='center',zorder=5, fontweight='medium')
            t = coord[1]

    #ax[i].set_title(c.replace(' ','\n').replace('nao\npuras','nao puras'), ha='left', x=0)
    ax[i].xaxis.set_label_text('')

    ax[i].xaxis.set_ticks(group_df['Lmin'].to_list())
    ax[i].tick_params(axis='x', color='white', labelcolor='black', labelsize=9, rotation=90, pad=-2)

    [t.set_color('#aaaaaa') for t in ax[i].yaxis.get_ticklabels()]
    [t.set_va('bottom') for t in ax[i].yaxis.get_ticklabels()]
    ax[i].yaxis.set_major_locator(MaxNLocator(integer=True))
    ax[i].yaxis.set_ticklabels([t for t in ax[i].yaxis.get_ticklabels()])
    #ax[i].xaxis.set_ticklabels([])
    ax[i].yaxis.set_ticklabels([])
    ax[i].yaxis.set_label_text('')
    ax[i].tick_params(axis='y', color='white')

    if j==0:
        ax[i].set_ylabel('$L_{min}$', loc='top', va='top', fontsize=12, fontweight='medium')
        #ax[i].yaxis.set_label_text('$L_{min}$')
        ax[i].yaxis.label.set_color('deeppink')
        ax[i].yaxis.label.set_rotation(0)

    ax[i].grid(axis='y', visible=True, color='#eeeeee')
    ax[i].grid(axis='x', visible=True, color='#eeeeee')
    ax[i].set_facecolor("white")

fig.tight_layout()
plt.savefig(f'docs/analise_params_{location}.png', bbox_inches='tight')
plt.show()

# %%
df_lmin.plot.scatter(x='recall', y='precision')
plt.savefig(f'docs/f1-score_lmin_{location}.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(1,1,figsize=(6, 6), dpi=150) # Adjust figure size as needed
sns.heatmap(df_lmin.corr(method='spearman'), annot=True, cmap='coolwarm', fmt=".2f", ax=ax, linewidth=.1, robust=True)
ax.set_title('Matriz de correlação (spearman)\n', fontsize=14, ha='left', x=0, weight='bold')
ax.tick_params(axis='y', color='white')
ax.tick_params(axis='x', color='white')
plt.savefig(f'docs/corr-spearman_lmin_{location}.png', bbox_inches='tight')
plt.show()

# %%
df_apr.plot.scatter(x='recall', y='precision')
plt.savefig(f'docs/f1-score_apr_{location}.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(1,1,figsize=(6, 6), dpi=150) # Adjust figure size as needed
sns.heatmap(df_apr.corr(method='spearman'), annot=True, cmap='coolwarm', fmt=".2f", ax=ax, linewidth=.1, robust=True)
ax.set_title('Matriz de correlação (spearman)\n', fontsize=14, ha='left', x=0, weight='bold')
ax.tick_params(axis='y', color='white')
ax.tick_params(axis='x', color='white')
plt.savefig(f'docs/corr-spearman_apr_{location}.png', bbox_inches='tight')
plt.show()
