# %% [markdown]
# # Comparability for 2010-2020 Census Tracts in New York City (NYC)

# %%
from utils import *

# %%
C1 = '2010'
C2 = '2020'
location = 'NYC'

BASENAME = f'{C1}_{C2}_{location}' # Nome da compatibilização
NAME_C1 = f'{location}_{C1}' # Nome da primeira malha censitária
NAME_C2 = f'{location}_{C2}' # Nome da segunda malha censitária

# %% [markdown]
# ## 1. Census layers pre-processing
# The following cell pre-processes the census layers and only needs to run once

# %%
# Place codes
counties = ['36081', '36061', '36085', '36005', '36047']

# Criação das malhas
layer_2010 = makeCensusLayer('resources/us_census_ny/Tracts US Census Bureau.gpkg',
                            id_column='GEOID10', 
                            layer='NY_2010',
                            filter=counties,
                            len_higher_hierarchy=7,
                            geosys='WGS84')
layer_2022 = makeCensusLayer('resources/us_census_ny/Tracts US Census Bureau.gpkg', 
                            id_column='GEOID', 
                            layer='NY_2020',
                            filter=counties,
                            len_higher_hierarchy=7,
                            geosys='WGS84')

# Exportação
layer_2010.to_parquet(f'results/{NAME_C1}.parquet')
layer_2022.to_parquet(f'results/{NAME_C2}.parquet')
# Out:
# 'makeCensusLayer' executed in 10.5519s.
# 'makeCensusLayer' executed in 5.0163s.

# %%
# Importação
layer_2010 = gpd.read_parquet(f'results/{NAME_C1}.parquet')
layer_2022 = gpd.read_parquet(f'results/{NAME_C2}.parquet')

# %% [markdown]
# ## 2. Comparability graph

# %%
G_compat = comparability_graph(layer_2010, layer_2022)
# Out:
# 'comparability_graph.makeGridUnion' executed in 5.7355s.
# 'getNeighborhoods' executed in 0.0031s.
# 'getNeighborhoods' executed in 0.0000s.
# 'comparability_graph.classifyGridChanges' executed in 0.2528s.
# 'comparability_graph.__init__' executed in 6.2838s.

# %%
G_compat.findMaintenances()
G_compat.findSplitings(threshold=0.8)

# Aplica séries de buffers
for b in [-20, -10]:
    G_compat.forceOverlay(buffer=b)

# Sobreposição de isolados restantes
G_compat.forceOverlay(buffer=0, use_all=True)
# Out:
# 'comparability_graph.findMaintenances' executed in 0.0107s.
# 'comparability_graph.findSplitings' executed in 0.0304s.
# 'comparability_graph.forceOverlay' executed in 0.1451s.
# 'comparability_graph.forceOverlay' executed in 0.0075s.
# 'comparability_graph.forceOverlay' executed in 0.0154s.

# %% [markdown]
# ## 3. Assessing gold standard

# %%
# Criação do grafo verdadeiro com dados do US Census Bureau
df_comp_truth = pd.read_csv('resources/us_census_ny/tab20_tract20_tract10_st36.txt', sep='|')

nodesA = [int(i[2:]) for i in G_compat.nodes() if i.startswith('A')]
nodesB = [int(i[2:]) for i in G_compat.nodes() if i.startswith('B')]
census_2010_2020 = df_comp_truth[['GEOID_TRACT_20','GEOID_TRACT_10']]
census_2010_2020 = census_2010_2020.query('GEOID_TRACT_20 in @nodesB | GEOID_TRACT_10 in @nodesA')

truth_graph = nx.Graph()

# Adiciona nós existentes
truth_graph.add_nodes_from(G_compat.nodes())

# Adiciona arestas verdadeiras
for _, r in census_2010_2020.iterrows():
    truth_graph.add_edge(f"A.{r['GEOID_TRACT_10']}", f"B.{r['GEOID_TRACT_20']}")

# Remove nós excedentes
exceeding_nodes = [i for i in truth_graph.nodes() if i not in G_compat.nodes()]
truth_graph.remove_nodes_from(exceeding_nodes)

# %%
G_compat.assessEdges(ground_truth_graph=truth_graph)
# Out:
# 'comparability_graph.assessEdges' executed in 0.0493s.

# %% [markdown]
# ## 4. Export results

# %%
G_compat.exportCompatFiles(BASENAME, NAME_C1, NAME_C2)
G_compat.reportCompat(file=f'results/{BASENAME}_report')
# Out:
# 'comparability_graph.exportCompatFiles' executed in 0.8832s.
# 'comparability_graph.reportCompat' executed in 0.0268s.
# {'params': {'A/P ratio': 0.3,
#   'Lmin': [0.8],
#   'Buffers': [{'buffer': -20, 'use_all': False},
#    {'buffer': -10, 'use_all': False},
#    {'buffer': 0, 'use_all': True}]},
#  'layers': {'Setores C1': 2168, 'Setores C2': 2327},
#  'relationships': {'Total relationships': {'n': 2426, 'pct': 1},
#   '': {'n': 98, 'pct': 0.0403957131079967},
#   'Divisão': {'n': 311, 'pct': 0.12819455894476506},
#   'Manutenção': {'n': 2011, 'pct': 0.8289365210222589},
#   'Sobreposição (-20m)': {'n': 6, 'pct': 0.00247320692497939}},
#  'operations': {'Total redesign operations': {'n': 2167, 'pct': 1},
#   '1:1': {'n': 2036, 'pct': 0.9395477618827872},
#   '1:n': {'n': 130, 'pct': 0.05999077065066913},
#   'm:n': {'n': 1, 'pct': 0.00046146746654360867}},
#  'metrics': {'Inconsistent maintenance': {'n': 0, 'pct': 0.0},
#   'Inconsistent splitting': {'n': 1.0, 'pct': 0.003215434083601286},
#   'Unconnected polygons': {'n': 0, 'pct': 0.0},
#   'Persistent unconnected': {'n': 0, 'pct': 0.0},
#   'Large redesigns': {'n': 0, 'pct': 0.0}},
#  'assessment': {'true positives': 2328,
#   'false positives': 0,
#   'false negatives': 98,
#   'recall': 0.9596042868920033,
#   'precision': 1.0,
#   'f1_score': 0.9793857803954565}}

# %% [markdown]
# ## 5. Parameter refinement test

# %%
for r in range(1,21):
    apr = round(0.1*r,2)
    print('\nTESTING A/P RATIO = ', apr)
    G_compat.reset(ap_ratio=apr)
    G_compat.findMaintenances()
    G_compat.findSplitings(threshold=0.8)
    # Aplica séries de buffers
    for b in [-20, -10]:
        G_compat.forceOverlay(buffer=b)
    # Sobreposição de isolados restantes
    G_compat.forceOverlay(buffer=0, use_all=True)

    G_compat.assessEdges(ground_truth_graph=truth_graph)

    G_compat.exportCompatFiles(BASENAME, NAME_C1, NAME_C2, save_files=False)
    G_compat.reportCompat(file=f'results/params/{BASENAME}_apr{str(apr).replace(".",",")}_report')
# Out:
# TESTING A/P RATIO =  0.1
# 'comparability_graph.reset' executed in 0.2986s.
# 'comparability_graph.findMaintenances' executed in 0.0000s.
# 'comparability_graph.findSplitings' executed in 0.0446s.
# 'comparability_graph.forceOverlay' executed in 0.1578s.
# 'comparability_graph.forceOverlay' executed in 0.0100s.
# 'comparability_graph.forceOverlay' executed in 0.0099s.
# 'comparability_graph.assessEdges' executed in 0.0419s.
# 'comparability_graph.exportCompatFiles' executed in 0.7258s.
# 'comparability_graph.reportCompat' executed in 0.0277s.
#
# TESTING A/P RATIO =  0.2
# 'comparability_graph.reset' executed in 0.2969s.
# 'comparability_graph.findMaintenances' executed in 0.0089s.
# 'comparability_graph.findSplitings' executed in 0.0270s.
# 'comparability_graph.forceOverlay' executed in 0.1495s.
# 'comparability_graph.forceOverlay' executed in 0.0164s.
# 'comparability_graph.forceOverlay' executed in 0.0073s.
# 'comparability_graph.assessEdges' executed in 0.0508s.
# 'comparability_graph.exportCompatFiles' executed in 0.6572s.
# 'comparability_graph.reportCompat' executed in 0.0322s.
#
# TESTING A/P RATIO =  0.3
# 'comparability_graph.reset' executed in 0.3088s.
# 'comparability_graph.findMaintenances' executed in 0.0092s.
# 'comparability_graph.findSplitings' executed in 0.0712s.
# 'comparability_graph.forceOverlay' executed in 0.1914s.
# 'comparability_graph.forceOverlay' executed in 0.0081s.
# 'comparability_graph.forceOverlay' executed in 0.0132s.
# 'comparability_graph.assessEdges' executed in 0.0987s.
# 'comparability_graph.exportCompatFiles' executed in 0.6332s.
# 'comparability_graph.reportCompat' executed in 0.0333s.
#
# TESTING A/P RATIO =  0.4
# 'comparability_graph.reset' executed in 0.3000s.
# 'comparability_graph.findMaintenances' executed in 0.0093s.
# 'comparability_graph.findSplitings' executed in 0.0332s.
# 'comparability_graph.forceOverlay' executed in 0.1482s.
# 'comparability_graph.forceOverlay' executed in 0.0089s.
# 'comparability_graph.forceOverlay' executed in 0.0187s.
# 'comparability_graph.assessEdges' executed in 0.0429s.
# 'comparability_graph.exportCompatFiles' executed in 0.6600s.
# 'comparability_graph.reportCompat' executed in 0.0380s.
#
# TESTING A/P RATIO =  0.5
# 'comparability_graph.reset' executed in 0.3074s.
# 'comparability_graph.findMaintenances' executed in 0.0021s.
# 'comparability_graph.findSplitings' executed in 0.0309s.
# 'comparability_graph.forceOverlay' executed in 0.1507s.
# 'comparability_graph.forceOverlay' executed in 0.0162s.
# 'comparability_graph.forceOverlay' executed in 0.0000s.
# 'comparability_graph.assessEdges' executed in 0.1005s.
# 'comparability_graph.exportCompatFiles' executed in 0.6837s.
# 'comparability_graph.reportCompat' executed in 0.0165s.
#
# TESTING A/P RATIO =  0.6
# 'comparability_graph.reset' executed in 0.3182s.
# 'comparability_graph.findMaintenances' executed in 0.0051s.
# 'comparability_graph.findSplitings' executed in 0.0282s.
# 'comparability_graph.forceOverlay' executed in 0.1483s.
# 'comparability_graph.forceOverlay' executed in 0.0157s.
# 'comparability_graph.forceOverlay' executed in 0.0065s.
# 'comparability_graph.assessEdges' executed in 0.0433s.
# 'comparability_graph.exportCompatFiles' executed in 0.7068s.
# 'comparability_graph.reportCompat' executed in 0.0326s.
#
# TESTING A/P RATIO =  0.7
# 'comparability_graph.reset' executed in 0.3095s.
# 'comparability_graph.findMaintenances' executed in 0.0051s.
# 'comparability_graph.findSplitings' executed in 0.0303s.
# 'comparability_graph.forceOverlay' executed in 0.1630s.
# 'comparability_graph.forceOverlay' executed in 0.0086s.
# 'comparability_graph.forceOverlay' executed in 0.0096s.
# 'comparability_graph.assessEdges' executed in 0.0432s.
# 'comparability_graph.exportCompatFiles' executed in 0.6590s.
# 'comparability_graph.reportCompat' executed in 0.0248s.
#
# TESTING A/P RATIO =  0.8
# 'comparability_graph.reset' executed in 0.3149s.
# 'comparability_graph.findMaintenances' executed in 0.0057s.
# 'comparability_graph.findSplitings' executed in 0.0296s.
# 'comparability_graph.forceOverlay' executed in 0.1489s.
# 'comparability_graph.forceOverlay' executed in 0.0108s.
# 'comparability_graph.forceOverlay' executed in 0.0045s.
# 'comparability_graph.assessEdges' executed in 0.1138s.
# 'comparability_graph.exportCompatFiles' executed in 0.6513s.
# 'comparability_graph.reportCompat' executed in 0.0352s.
#
# TESTING A/P RATIO =  0.9
# 'comparability_graph.reset' executed in 0.2993s.
# 'comparability_graph.findMaintenances' executed in 0.0099s.
# 'comparability_graph.findSplitings' executed in 0.0193s.
# 'comparability_graph.forceOverlay' executed in 0.1580s.
# 'comparability_graph.forceOverlay' executed in 0.0120s.
# 'comparability_graph.forceOverlay' executed in 0.0111s.
# 'comparability_graph.assessEdges' executed in 0.0436s.
# 'comparability_graph.exportCompatFiles' executed in 0.6665s.
# 'comparability_graph.reportCompat' executed in 0.0277s.
#
# TESTING A/P RATIO =  1.0
# 'comparability_graph.reset' executed in 0.3661s.
# 'comparability_graph.findMaintenances' executed in 0.0066s.
# 'comparability_graph.findSplitings' executed in 0.0293s.
# 'comparability_graph.forceOverlay' executed in 0.1429s.
# 'comparability_graph.forceOverlay' executed in 0.0053s.
# 'comparability_graph.forceOverlay' executed in 0.0191s.
# 'comparability_graph.assessEdges' executed in 0.1089s.
# 'comparability_graph.exportCompatFiles' executed in 0.6640s.
# 'comparability_graph.reportCompat' executed in 0.0321s.
#
# TESTING A/P RATIO =  1.1
# 'comparability_graph.reset' executed in 0.3101s.
# 'comparability_graph.findMaintenances' executed in 0.0154s.
# 'comparability_graph.findSplitings' executed in 0.0301s.
# 'comparability_graph.forceOverlay' executed in 0.1539s.
# 'comparability_graph.forceOverlay' executed in 0.0040s.
# 'comparability_graph.forceOverlay' executed in 0.0119s.
# 'comparability_graph.assessEdges' executed in 0.0539s.
# 'comparability_graph.exportCompatFiles' executed in 0.7428s.
# 'comparability_graph.reportCompat' executed in 0.0194s.
#
# TESTING A/P RATIO =  1.2
# 'comparability_graph.reset' executed in 0.3134s.
# 'comparability_graph.findMaintenances' executed in 0.0000s.
# 'comparability_graph.findSplitings' executed in 0.0330s.
# 'comparability_graph.forceOverlay' executed in 0.1629s.
# 'comparability_graph.forceOverlay' executed in 0.0043s.
# 'comparability_graph.forceOverlay' executed in 0.0165s.
# 'comparability_graph.assessEdges' executed in 0.0488s.
# 'comparability_graph.exportCompatFiles' executed in 0.6866s.
# 'comparability_graph.reportCompat' executed in 0.0183s.
#
# TESTING A/P RATIO =  1.3
# 'comparability_graph.reset' executed in 0.3155s.
# 'comparability_graph.findMaintenances' executed in 0.0060s.
# 'comparability_graph.findSplitings' executed in 0.0288s.
# 'comparability_graph.forceOverlay' executed in 0.2090s.
# 'comparability_graph.forceOverlay' executed in 0.0103s.
# 'comparability_graph.forceOverlay' executed in 0.0133s.
# 'comparability_graph.assessEdges' executed in 0.0449s.
# 'comparability_graph.exportCompatFiles' executed in 0.6669s.
# 'comparability_graph.reportCompat' executed in 0.0296s.
#
# TESTING A/P RATIO =  1.4
# 'comparability_graph.reset' executed in 0.3131s.
# 'comparability_graph.findMaintenances' executed in 0.0064s.
# 'comparability_graph.findSplitings' executed in 0.0303s.
# 'comparability_graph.forceOverlay' executed in 0.1567s.
# 'comparability_graph.forceOverlay' executed in 0.0099s.
# 'comparability_graph.forceOverlay' executed in 0.0107s.
# 'comparability_graph.assessEdges' executed in 0.0294s.
# 'comparability_graph.exportCompatFiles' executed in 0.7105s.
# 'comparability_graph.reportCompat' executed in 0.0293s.
#
# TESTING A/P RATIO =  1.5
# 'comparability_graph.reset' executed in 0.2990s.
# 'comparability_graph.findMaintenances' executed in 0.0053s.
# 'comparability_graph.findSplitings' executed in 0.0290s.
# 'comparability_graph.forceOverlay' executed in 0.1451s.
# 'comparability_graph.forceOverlay' executed in 0.0141s.
# 'comparability_graph.forceOverlay' executed in 0.0000s.
# 'comparability_graph.assessEdges' executed in 0.0502s.
# 'comparability_graph.exportCompatFiles' executed in 0.6663s.
# 'comparability_graph.reportCompat' executed in 0.0197s.
#
# TESTING A/P RATIO =  1.6
# 'comparability_graph.reset' executed in 0.2998s.
# 'comparability_graph.findMaintenances' executed in 0.0158s.
# 'comparability_graph.findSplitings' executed in 0.0345s.
# 'comparability_graph.forceOverlay' executed in 0.1656s.
# 'comparability_graph.forceOverlay' executed in 0.0085s.
# 'comparability_graph.forceOverlay' executed in 0.0134s.
# 'comparability_graph.assessEdges' executed in 0.0459s.
# 'comparability_graph.exportCompatFiles' executed in 0.7470s.
# 'comparability_graph.reportCompat' executed in 0.0227s.
#
# TESTING A/P RATIO =  1.7
# 'comparability_graph.reset' executed in 0.3135s.
# 'comparability_graph.findMaintenances' executed in 0.0059s.
# 'comparability_graph.findSplitings' executed in 0.0297s.
# 'comparability_graph.forceOverlay' executed in 0.1516s.
# 'comparability_graph.forceOverlay' executed in 0.0096s.
# 'comparability_graph.forceOverlay' executed in 0.0100s.
# 'comparability_graph.assessEdges' executed in 0.0457s.
# 'comparability_graph.exportCompatFiles' executed in 0.6667s.
# 'comparability_graph.reportCompat' executed in 0.0328s.
#
# TESTING A/P RATIO =  1.8
# 'comparability_graph.reset' executed in 0.3114s.
# 'comparability_graph.findMaintenances' executed in 0.0060s.
# 'comparability_graph.findSplitings' executed in 0.0337s.
# 'comparability_graph.forceOverlay' executed in 0.1590s.
# 'comparability_graph.forceOverlay' executed in 0.0106s.
# 'comparability_graph.forceOverlay' executed in 0.0105s.
# 'comparability_graph.assessEdges' executed in 0.0955s.
# 'comparability_graph.exportCompatFiles' executed in 0.6553s.
# 'comparability_graph.reportCompat' executed in 0.0283s.
#
# TESTING A/P RATIO =  1.9
# 'comparability_graph.reset' executed in 0.3071s.
# 'comparability_graph.findMaintenances' executed in 0.0062s.
# 'comparability_graph.findSplitings' executed in 0.0300s.
# 'comparability_graph.forceOverlay' executed in 0.1535s.
# 'comparability_graph.forceOverlay' executed in 0.0097s.
# 'comparability_graph.forceOverlay' executed in 0.0105s.
# 'comparability_graph.assessEdges' executed in 0.0356s.
# 'comparability_graph.exportCompatFiles' executed in 0.6506s.
# 'comparability_graph.reportCompat' executed in 0.0416s.
#
# TESTING A/P RATIO =  2.0
# 'comparability_graph.reset' executed in 0.3571s.
# 'comparability_graph.findMaintenances' executed in 0.0137s.
# 'comparability_graph.findSplitings' executed in 0.0318s.
# 'comparability_graph.forceOverlay' executed in 0.1555s.
# 'comparability_graph.forceOverlay' executed in 0.0110s.
# 'comparability_graph.forceOverlay' executed in 0.0123s.
# 'comparability_graph.assessEdges' executed in 0.0495s.
# 'comparability_graph.exportCompatFiles' executed in 0.6777s.
# 'comparability_graph.reportCompat' executed in 0.0271s.

# %%
for r in range(1,11):
    lmin = round(0.1 * r,2)

    print('\nTESTING Lmin = ', lmin)
    G_compat.reset()
    G_compat.findMaintenances()
    G_compat.findSplitings(threshold=lmin)
    # Aplica séries de buffers
    for b in [-20, -10]:
        G_compat.forceOverlay(buffer=b)
    # Sobreposição de isolados restantes
    G_compat.forceOverlay(buffer=0, use_all=True)

    G_compat.assessEdges(ground_truth_graph=truth_graph)

    G_compat.exportCompatFiles(BASENAME, NAME_C1, NAME_C2, save_files=False)
    G_compat.reportCompat(file=f'results/params/{BASENAME}_lmin{str(lmin).replace(".",",")}_report.json')
# Out:
# TESTING Lmin =  0.1
# 'comparability_graph.reset' executed in 0.3145s.
# 'comparability_graph.findMaintenances' executed in 0.0073s.
# 'comparability_graph.findSplitings' executed in 0.0288s.
# 'comparability_graph.forceOverlay' executed in 0.0824s.
# 'comparability_graph.forceOverlay' executed in 0.0111s.
# 'comparability_graph.forceOverlay' executed in 0.0110s.
# 'comparability_graph.assessEdges' executed in 0.1274s.
# 'comparability_graph.exportCompatFiles' executed in 0.7510s.
# 'comparability_graph.reportCompat' executed in 0.0311s.
#
# TESTING Lmin =  0.2
# 'comparability_graph.reset' executed in 0.2970s.
# 'comparability_graph.findMaintenances' executed in 0.0142s.
# 'comparability_graph.findSplitings' executed in 0.0308s.
# 'comparability_graph.forceOverlay' executed in 0.0679s.
# 'comparability_graph.forceOverlay' executed in 0.0090s.
# 'comparability_graph.forceOverlay' executed in 0.0142s.
# 'comparability_graph.assessEdges' executed in 0.0426s.
# 'comparability_graph.exportCompatFiles' executed in 0.7087s.
# 'comparability_graph.reportCompat' executed in 0.0306s.
#
# TESTING Lmin =  0.3
# 'comparability_graph.reset' executed in 0.2992s.
# 'comparability_graph.findMaintenances' executed in 0.0052s.
# 'comparability_graph.findSplitings' executed in 0.0300s.
# 'comparability_graph.forceOverlay' executed in 0.1309s.
# 'comparability_graph.forceOverlay' executed in 0.0167s.
# 'comparability_graph.forceOverlay' executed in 0.0154s.
# 'comparability_graph.assessEdges' executed in 0.0423s.
# 'comparability_graph.exportCompatFiles' executed in 0.6426s.
# 'comparability_graph.reportCompat' executed in 0.0323s.
#
# TESTING Lmin =  0.4
# 'comparability_graph.reset' executed in 0.3081s.
# 'comparability_graph.findMaintenances' executed in 0.0063s.
# 'comparability_graph.findSplitings' executed in 0.0296s.
# 'comparability_graph.forceOverlay' executed in 0.1465s.
# 'comparability_graph.forceOverlay' executed in 0.0098s.
# 'comparability_graph.forceOverlay' executed in 0.0106s.
# 'comparability_graph.assessEdges' executed in 0.1041s.
# 'comparability_graph.exportCompatFiles' executed in 0.6513s.
# 'comparability_graph.reportCompat' executed in 0.0291s.
#
# TESTING Lmin =  0.5
# 'comparability_graph.reset' executed in 0.3050s.
# 'comparability_graph.findMaintenances' executed in 0.0000s.
# 'comparability_graph.findSplitings' executed in 0.0369s.
# 'comparability_graph.forceOverlay' executed in 0.1482s.
# 'comparability_graph.forceOverlay' executed in 0.0096s.
# 'comparability_graph.forceOverlay' executed in 0.0098s.
# 'comparability_graph.assessEdges' executed in 0.0441s.
# 'comparability_graph.exportCompatFiles' executed in 0.6518s.
# 'comparability_graph.reportCompat' executed in 0.0461s.
#
# TESTING Lmin =  0.6
# 'comparability_graph.reset' executed in 0.3042s.
# 'comparability_graph.findMaintenances' executed in 0.0696s.
# 'comparability_graph.findSplitings' executed in 0.0319s.
# 'comparability_graph.forceOverlay' executed in 0.1463s.
# 'comparability_graph.forceOverlay' executed in 0.0024s.
# 'comparability_graph.forceOverlay' executed in 0.0198s.
# 'comparability_graph.assessEdges' executed in 0.0440s.
# 'comparability_graph.exportCompatFiles' executed in 0.6695s.
# 'comparability_graph.reportCompat' executed in 0.0323s.
#
# TESTING Lmin =  0.7
# 'comparability_graph.reset' executed in 0.3008s.
# 'comparability_graph.findMaintenances' executed in 0.0005s.
# 'comparability_graph.findSplitings' executed in 0.0333s.
# 'comparability_graph.forceOverlay' executed in 0.1510s.
# 'comparability_graph.forceOverlay' executed in 0.0106s.
# 'comparability_graph.forceOverlay' executed in 0.0103s.
# 'comparability_graph.assessEdges' executed in 0.0435s.
# 'comparability_graph.exportCompatFiles' executed in 0.6996s.
# 'comparability_graph.reportCompat' executed in 0.0293s.
#
# TESTING Lmin =  0.8
# 'comparability_graph.reset' executed in 0.3039s.
# 'comparability_graph.findMaintenances' executed in 0.0062s.
# 'comparability_graph.findSplitings' executed in 0.0296s.
# 'comparability_graph.forceOverlay' executed in 0.1506s.
# 'comparability_graph.forceOverlay' executed in 0.0101s.
# 'comparability_graph.forceOverlay' executed in 0.0107s.
# 'comparability_graph.assessEdges' executed in 0.0454s.
# 'comparability_graph.exportCompatFiles' executed in 0.6469s.
# 'comparability_graph.reportCompat' executed in 0.0199s.
#
# TESTING Lmin =  0.9
# 'comparability_graph.reset' executed in 0.3124s.
# 'comparability_graph.findMaintenances' executed in 0.0047s.
# 'comparability_graph.findSplitings' executed in 0.0167s.
# 'comparability_graph.forceOverlay' executed in 0.2280s.
# 'comparability_graph.forceOverlay' executed in 0.0112s.
# 'comparability_graph.forceOverlay' executed in 0.0101s.
# 'comparability_graph.assessEdges' executed in 0.0460s.
# 'comparability_graph.exportCompatFiles' executed in 0.6701s.
# 'comparability_graph.reportCompat' executed in 0.0268s.
#
# TESTING Lmin =  1.0
# 'comparability_graph.reset' executed in 0.3079s.
# 'comparability_graph.findMaintenances' executed in 0.0041s.
# 'comparability_graph.findSplitings' executed in 0.0246s.
# 'comparability_graph.forceOverlay' executed in 0.5502s.
# 'comparability_graph.forceOverlay' executed in 0.0131s.
# 'comparability_graph.forceOverlay' executed in 0.0111s.
# 'comparability_graph.assessEdges' executed in 0.0404s.
# 'comparability_graph.exportCompatFiles' executed in 0.6622s.
# 'comparability_graph.reportCompat' executed in 0.0281s.

# %%
df_apr = readMetrics(BASENAME, 'apr')
df_lmin = readMetrics(BASENAME, 'lmin')

# %%
from matplotlib import pyplot as plt
from matplotlib.ticker import MaxNLocator
params = {'mathtext.default': 'regular' , 'font.family':'Roboto'} 
plt.rcParams.update(params)
import seaborn as sns

labels = {
    'Inconsistent maintenance': 'Inconsistent\nmaintenance',
    'Inconsistent splitting':'Inconsistent\nsplitting',
    'Unconnected polygons':'Unconnected\npolygons',
    'Persistent unconnected':'Persistent\nunconnected',
    'Large redesigns':'Large\nredesigns',
    'recall': 'Recall\n(×1000)',
    'precision': 'Precision\n(×1000)',
    'f1_score': 'F1-Score\n(×1000)'
}

fig, ax = plt.subplots(2,len(df_apr.columns)-1,figsize=(15, 4), dpi=150)

for j, c in enumerate([i for i in df_apr.columns if i != 'A/P ratio']):
    i = (0,j)
    group_df = df_apr[['A/P ratio', c]]
    sns.lineplot(x='A/P ratio',y=c, data=group_df, color='blue', ax=ax[i], marker='None')

    # Anotações
    coords = [(x, y) for x,y in zip(group_df['A/P ratio'], group_df[c])]
    t=None
    for coord in coords[::2]:
        if coord[1]!=t:
            t = ax[i].annotate(f'{round(coord[1],0):n}', fontsize=4, xy=coord, textcoords='data', ha='center', va='center', color='white')
            t.set_bbox(dict(facecolor='white', alpha=1, linewidth=0, boxstyle='round,pad=0.8'))
            t = coord[1]
    t=None
    for coord in coords[::2]:
        if coord[1]!=t:
            ax[i].annotate(f'{round(coord[1],0):n}', fontsize=7, color='blue', xy=coord, textcoords='data', ha='center', va='center',zorder=5, fontweight='medium')
            t = coord[1]

    ax[i].set_title(labels[c], fontsize=13, ha='left', x=0)
    ax[i].xaxis.set_label_text('')

    ax[i].xaxis.set_ticks(group_df['A/P ratio'].to_list()[::2])
    ax[i].tick_params(axis='x', color='white', labelcolor='black', labelsize=9, rotation=90, pad=-2)

    [t.set_color('#aaaaaa') for t in ax[i].yaxis.get_ticklabels()]
    [t.set_va('bottom') for t in ax[i].yaxis.get_ticklabels()]
    ax[i].yaxis.set_major_locator(MaxNLocator(integer=True))
    ax[i].yaxis.set_ticklabels([t for t in ax[i].yaxis.get_ticklabels()])
    #ax[i].xaxis.set_ticklabels([])
    ax[i].yaxis.set_ticklabels([])
    ax[i].yaxis.set_label_text('')
    ax[i].tick_params(axis='y', color='white')

    if j==0:
        ax[i].set_ylabel('A/P', loc='top', va='top', fontsize=12, fontweight='medium')
        #ax[i].yaxis.set_label_text(r'A/P')
        ax[i].yaxis.label.set_color('blue')
        ax[i].yaxis.label.set_rotation(0)

    ax[i].grid(axis='y', visible=True, color='#eeeeee')
    ax[i].grid(axis='x', visible=True, color='#eeeeee')
    ax[i].set_facecolor("white")

for j, c in enumerate([i for i in df_lmin.columns if i != 'Lmin']):
    i = (1,j)
    group_df = df_lmin[['Lmin', c]]
    sns.lineplot(x='Lmin',y=c, data=group_df, color='deeppink', ax=ax[i], marker='None')

    # Anotações
    coords = [(x, y) for x,y in zip(group_df['Lmin'], group_df[c])]
    t=None
    for coord in coords:
        if coord[1]!=t:
            t = ax[i].annotate(f'{round(coord[1],0):n}', fontsize=4, xy=coord, textcoords='data', ha='center', va='center', color='white')
            t.set_bbox(dict(facecolor='white', alpha=1, linewidth=0, boxstyle='round,pad=0.8'))
            t = coord[1]
    t=None
    for coord in coords:
        if coord[1]!=t:
            ax[i].annotate(f'{round(coord[1],0):n}', fontsize=7, color='deeppink', xy=coord, textcoords='data', ha='center', va='center',zorder=5, fontweight='medium')
            t = coord[1]

    #ax[i].set_title(c.replace(' ','\n').replace('nao\npuras','nao puras'), ha='left', x=0)
    ax[i].xaxis.set_label_text('')

    ax[i].xaxis.set_ticks(group_df['Lmin'].to_list())
    ax[i].tick_params(axis='x', color='white', labelcolor='black', labelsize=9, rotation=90, pad=-2)

    [t.set_color('#aaaaaa') for t in ax[i].yaxis.get_ticklabels()]
    [t.set_va('bottom') for t in ax[i].yaxis.get_ticklabels()]
    ax[i].yaxis.set_major_locator(MaxNLocator(integer=True))
    ax[i].yaxis.set_ticklabels([t for t in ax[i].yaxis.get_ticklabels()])
    #ax[i].xaxis.set_ticklabels([])
    ax[i].yaxis.set_ticklabels([])
    ax[i].yaxis.set_label_text('')
    ax[i].tick_params(axis='y', color='white')

    if j==0:
        ax[i].set_ylabel('$L_{min}$', loc='top', va='top', fontsize=12, fontweight='medium')
        #ax[i].yaxis.set_label_text('$L_{min}$')
        ax[i].yaxis.label.set_color('deeppink')
        ax[i].yaxis.label.set_rotation(0)

    ax[i].grid(axis='y', visible=True, color='#eeeeee')
    ax[i].grid(axis='x', visible=True, color='#eeeeee')
    ax[i].set_facecolor("white")

fig.tight_layout()
plt.savefig(f'docs/analise_params_{location}.png', bbox_inches='tight')
plt.show()

# %%
df_lmin.plot.scatter(x='recall', y='precision')
plt.savefig(f'docs/f1-score_lmin_{location}.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(1,1,figsize=(6, 6), dpi=150) # Adjust figure size as needed
sns.heatmap(df_lmin.corr(method='spearman'), annot=True, cmap='coolwarm', fmt=".2f", ax=ax, linewidth=.1, robust=True)
ax.set_title('Matriz de correlação (spearman)\n', fontsize=14, ha='left', x=0, weight='bold')
ax.tick_params(axis='y', color='white')
ax.tick_params(axis='x', color='white')
plt.savefig(f'docs/corr-spearman_lmin_{location}.png', bbox_inches='tight')
plt.show()

# %%
df_apr.plot.scatter(x='recall', y='precision')
plt.savefig(f'docs/f1-score_apr_{location}.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(1,1,figsize=(6, 6), dpi=150) # Adjust figure size as needed
sns.heatmap(df_apr.corr(method='spearman'), annot=True, cmap='coolwarm', fmt=".2f", ax=ax, linewidth=.1, robust=True)
ax.set_title('Matriz de correlação (spearman)\n', fontsize=14, ha='left', x=0, weight='bold')
ax.tick_params(axis='y', color='white')
ax.tick_params(axis='x', color='white')
plt.savefig(f'docs/corr-spearman_apr_{location}.png', bbox_inches='tight')
plt.show()
