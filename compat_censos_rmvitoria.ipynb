# %% [markdown]
# # Comparability for 2010-2022 Census Tracts in Vitória Metropolitan Region (RMVitoria)

# %%
from utils import *

# %%
C1 = '2010'
C2 = '2022'
location = 'RMVitoria'

BASENAME = f'{C1}_{C2}_{location}' # Nome da compatibilização
NAME_C1 = f'{location}_{C1}' # Nome da primeira malha censitária
NAME_C2 = f'{location}_{C2}' # Nome da segunda malha censitária

# %% [markdown]
# ## 1. Census layers pre-processing
# The following cell pre-processes the census layers and only needs to run once

# %%
# Códigos de municípios
muns = ['3205309','3205002','3202207','3205200','3205101','3202405','3201308']

# Criação das malhas
layer_2010 = makeCensusLayer('resources/ibge/Setores IBGE.gpkg',
                            id_column='CD_GEOCODI', 
                            layer='ES_2010',
                            len_higher_hierarchy=9,
                            filter=muns,
                            geosys='SIRGAS2000')
layer_2022 = makeCensusLayer('resources/ibge/Setores IBGE.gpkg', 
                            id_column='CD_SETOR', 
                            layer='ES_2022',
                            len_higher_hierarchy=9,
                            filter=muns,
                            geosys='SIRGAS2000')

# Exportação
layer_2010.to_parquet(f'results/{NAME_C1}.parquet')
layer_2022.to_parquet(f'results/{NAME_C2}.parquet')
# Out:
# 'makeCensusLayer' executed in 6.0821s.
# 'makeCensusLayer' executed in 9.5198s.

# %%
# Importação
layer_2010 = gpd.read_parquet(f'results/{NAME_C1}.parquet')
layer_2022 = gpd.read_parquet(f'results/{NAME_C2}.parquet')

# %% [markdown]
# ## 2. Comparability graph

# %%
G_compat = comparability_graph(layer_2010, layer_2022)
# Out:
# 'comparability_graph.makeGridUnion' executed in 16.5201s.
# 'getNeighborhoods' executed in 0.0000s.
# 'getNeighborhoods' executed in 0.0166s.
# 'comparability_graph.classifyGridChanges' executed in 0.3533s.
# 'comparability_graph.__init__' executed in 17.3247s.

# %%
G_compat.findMaintenances()
G_compat.findSplitings(threshold=0.8)

# Aplica séries de buffers
for b in [-20, -10]:
    G_compat.forceOverlay(buffer=b)

# Sobreposição de isolados restantes
G_compat.forceOverlay(buffer=0, use_all=True)
# Out:
# 'comparability_graph.findMaintenances' executed in 0.0056s.
# 'comparability_graph.findSplitings' executed in 0.1466s.
# 'comparability_graph.forceOverlay' executed in 1.9778s.
# 'comparability_graph.forceOverlay' executed in 0.8835s.
# 'comparability_graph.forceOverlay' executed in 1.1928s.

# %% [markdown]
# ## 3. Assessing gold standard

# %%
# Criação do grafo verdadeiro com dados do IBGE
df_comp_ibge = pd.read_excel('resources/ibge/Historico_formacao_Setores_Censitarios_2010_2022.xlsx')

nodesA = [int(i[2:]) for i in G_compat.nodes() if i.startswith('A')]
nodesB = [int(i[2:]) for i in G_compat.nodes() if i.startswith('B')]
ibge_2010_2022 = df_comp_ibge[['GEOCODIGO_2022_DIVULGAÇÃO','GEOCODIGO_2010']]
ibge_2010_2022 = ibge_2010_2022.query('GEOCODIGO_2022_DIVULGAÇÃO in @nodesB | GEOCODIGO_2010 in @nodesA')

truth_graph = nx.Graph()

# Adiciona nós existentes
truth_graph.add_nodes_from(G_compat.nodes())

# Adiciona arestas verdadeiras
for _, r in ibge_2010_2022.iterrows():
    truth_graph.add_edge(f"A.{r['GEOCODIGO_2010']}", f"B.{r['GEOCODIGO_2022_DIVULGAÇÃO']}")

# Remove nós excedentes
exceeding_nodes = [i for i in truth_graph.nodes() if i not in G_compat.nodes()]
truth_graph.remove_nodes_from(exceeding_nodes)

# %%
G_compat.assessEdges(ground_truth_graph=truth_graph)
# Out:
# 'comparability_graph.assessEdges' executed in 0.0994s.

# %% [markdown]
# ## 4. Export results

# %%
G_compat.exportCompatFiles(BASENAME, NAME_C1, NAME_C2)
G_compat.reportCompat(file=f'results/{BASENAME}_report')
# Out:
# 'comparability_graph.exportCompatFiles' executed in 1.5418s.
# 'comparability_graph.reportCompat' executed in 0.0320s.
# {'params': {'A/P ratio': 0.3,
#   'Lmin': [0.8],
#   'Buffers': [{'buffer': -20, 'use_all': False},
#    {'buffer': -10, 'use_all': False},
#    {'buffer': 0, 'use_all': True}]},
#  'layers': {'Setores C1': 2867, 'Setores C2': 3957},
#  'relationships': {'Total relationships': {'n': 4249, 'pct': 1},
#   '': {'n': 72, 'pct': 0.016945163567898328},
#   'Divisão': {'n': 1919, 'pct': 0.4516356789832902},
#   'Manutenção': {'n': 1556, 'pct': 0.3662038126618028},
#   'Manutenção desassociada': {'n': 4, 'pct': 0.0009413979759943516},
#   'Sobreposição (-10m)': {'n': 8, 'pct': 0.0018827959519887032},
#   'Sobreposição (-20m)': {'n': 655, 'pct': 0.15415391856907507},
#   'Sobreposição (0m)': {'n': 35, 'pct': 0.008237232289950576}},
#  'operations': {'Total redesign operations': {'n': 2611, 'pct': 1},
#   '1:1': {'n': 2017, 'pct': 0.7725009574875527},
#   '1:n': {'n': 511, 'pct': 0.19571045576407506},
#   'm:n': {'n': 76, 'pct': 0.02910762160091919},
#   'n:1': {'n': 7, 'pct': 0.002680965147453083}},
#  'metrics': {'Inconsistent maintenance': {'n': 28,
#    'pct': 0.008997429305912597},
#   'Inconsistent splitting': {'n': 334.0, 'pct': 0.17404898384575299},
#   'Unconnected polygons': {'n': 28, 'pct': 0.00414630534577225},
#   'Persistent unconnected': {'n': 35, 'pct': 0.0051828816822153114},
#   'Large redesigns': {'n': 5, 'pct': 0.0019149751053236309}},
#  'assessment': {'true positives': 3878,
#   'false positives': 299,
#   'false negatives': 72,
#   'recall': 0.9817721518987341,
#   'precision': 0.928417524539143,
#   'f1_score': 0.954349698535745}}

# %%
G_compat.assess_df['assessment'].unique()
# Out:
# array(['true positive', 'false positive', 'false negative'], dtype=object)

# %% [markdown]
# ## 5. Parameter refinement test

# %%
for r in range(1,21):
    apr = round(0.1*r,2)
    print('\nTESTING A/P RATIO = ', apr)
    G_compat.reset(ap_ratio=apr)
    G_compat.findMaintenances()
    G_compat.findSplitings(threshold=0.8)
    # Aplica séries de buffers
    for b in [-20, -10]:
        G_compat.forceOverlay(buffer=b)
    # Sobreposição de isolados restantes
    G_compat.forceOverlay(buffer=0, use_all=True)

    G_compat.assessEdges(ground_truth_graph=truth_graph)

    G_compat.exportCompatFiles(BASENAME, NAME_C1, NAME_C2, save_files=False)
    G_compat.reportCompat(file=f'results/params/{BASENAME}_apr{str(apr).replace(".",",")}_report')
# Out:
# TESTING A/P RATIO =  0.1
# 'comparability_graph.reset' executed in 0.4600s.
# 'comparability_graph.findMaintenances' executed in 0.0047s.
# 'comparability_graph.findSplitings' executed in 0.1062s.
# 'comparability_graph.forceOverlay' executed in 1.9651s.
# 'comparability_graph.forceOverlay' executed in 0.8910s.
# 'comparability_graph.forceOverlay' executed in 1.1859s.
# 'comparability_graph.assessEdges' executed in 0.1323s.
# 'comparability_graph.exportCompatFiles' executed in 1.1417s.
# 'comparability_graph.reportCompat' executed in 0.0384s.
#
# TESTING A/P RATIO =  0.2
# 'comparability_graph.reset' executed in 0.4988s.
# 'comparability_graph.findMaintenances' executed in 0.0040s.
# 'comparability_graph.findSplitings' executed in 0.1092s.
# 'comparability_graph.forceOverlay' executed in 1.9683s.
# 'comparability_graph.forceOverlay' executed in 0.9375s.
# 'comparability_graph.forceOverlay' executed in 1.1916s.
# 'comparability_graph.assessEdges' executed in 0.0833s.
# 'comparability_graph.exportCompatFiles' executed in 1.1650s.
# 'comparability_graph.reportCompat' executed in 0.0294s.
#
# TESTING A/P RATIO =  0.3
# 'comparability_graph.reset' executed in 0.5177s.
# 'comparability_graph.findMaintenances' executed in 0.0035s.
# 'comparability_graph.findSplitings' executed in 0.1173s.
# 'comparability_graph.forceOverlay' executed in 2.0064s.
# 'comparability_graph.forceOverlay' executed in 0.8962s.
# 'comparability_graph.forceOverlay' executed in 1.1829s.
# 'comparability_graph.assessEdges' executed in 0.0761s.
# 'comparability_graph.exportCompatFiles' executed in 1.1982s.
# 'comparability_graph.reportCompat' executed in 0.0259s.
#
# TESTING A/P RATIO =  0.4
# 'comparability_graph.reset' executed in 0.4583s.
# 'comparability_graph.findMaintenances' executed in 0.0060s.
# 'comparability_graph.findSplitings' executed in 0.1101s.
# 'comparability_graph.forceOverlay' executed in 1.9758s.
# 'comparability_graph.forceOverlay' executed in 0.8866s.
# 'comparability_graph.forceOverlay' executed in 1.1942s.
# 'comparability_graph.assessEdges' executed in 0.0765s.
# 'comparability_graph.exportCompatFiles' executed in 1.2238s.
# 'comparability_graph.reportCompat' executed in 0.0285s.
#
# TESTING A/P RATIO =  0.5
# 'comparability_graph.reset' executed in 0.4641s.
# 'comparability_graph.findMaintenances' executed in 0.0048s.
# 'comparability_graph.findSplitings' executed in 0.1083s.
# 'comparability_graph.forceOverlay' executed in 1.9559s.
# 'comparability_graph.forceOverlay' executed in 0.8982s.
# 'comparability_graph.forceOverlay' executed in 1.1665s.
# 'comparability_graph.assessEdges' executed in 0.1185s.
# 'comparability_graph.exportCompatFiles' executed in 1.1598s.
# 'comparability_graph.reportCompat' executed in 0.0378s.
#
# TESTING A/P RATIO =  0.6
# 'comparability_graph.reset' executed in 0.4514s.
# 'comparability_graph.findMaintenances' executed in 0.0063s.
# 'comparability_graph.findSplitings' executed in 0.1151s.
# 'comparability_graph.forceOverlay' executed in 1.9642s.
# 'comparability_graph.forceOverlay' executed in 0.9557s.
# 'comparability_graph.forceOverlay' executed in 1.1879s.
# 'comparability_graph.assessEdges' executed in 0.0768s.
# 'comparability_graph.exportCompatFiles' executed in 1.1477s.
# 'comparability_graph.reportCompat' executed in 0.0333s.
#
# TESTING A/P RATIO =  0.7
# 'comparability_graph.reset' executed in 0.4641s.
# 'comparability_graph.findMaintenances' executed in 0.0553s.
# 'comparability_graph.findSplitings' executed in 0.1089s.
# 'comparability_graph.forceOverlay' executed in 1.9561s.
# 'comparability_graph.forceOverlay' executed in 0.9025s.
# 'comparability_graph.forceOverlay' executed in 1.1817s.
# 'comparability_graph.assessEdges' executed in 0.0784s.
# 'comparability_graph.exportCompatFiles' executed in 1.2219s.
# 'comparability_graph.reportCompat' executed in 0.0334s.
#
# TESTING A/P RATIO =  0.8
# 'comparability_graph.reset' executed in 0.4542s.
# 'comparability_graph.findMaintenances' executed in 0.0053s.
# 'comparability_graph.findSplitings' executed in 0.1073s.
# 'comparability_graph.forceOverlay' executed in 1.9727s.
# 'comparability_graph.forceOverlay' executed in 0.8877s.
# 'comparability_graph.forceOverlay' executed in 1.1815s.
# 'comparability_graph.assessEdges' executed in 0.1306s.
# 'comparability_graph.exportCompatFiles' executed in 1.1451s.
# 'comparability_graph.reportCompat' executed in 0.0251s.
#
# TESTING A/P RATIO =  0.9
# 'comparability_graph.reset' executed in 0.4672s.
# 'comparability_graph.findMaintenances' executed in 0.0060s.
# 'comparability_graph.findSplitings' executed in 0.1143s.
# 'comparability_graph.forceOverlay' executed in 1.9894s.
# 'comparability_graph.forceOverlay' executed in 0.9506s.
# 'comparability_graph.forceOverlay' executed in 1.2283s.
# 'comparability_graph.assessEdges' executed in 0.0722s.
# 'comparability_graph.exportCompatFiles' executed in 1.1692s.
# 'comparability_graph.reportCompat' executed in 0.0312s.
#
# TESTING A/P RATIO =  1.0
# 'comparability_graph.reset' executed in 0.4523s.
# 'comparability_graph.findMaintenances' executed in 0.0145s.
# 'comparability_graph.findSplitings' executed in 0.1049s.
# 'comparability_graph.forceOverlay' executed in 2.0292s.
# 'comparability_graph.forceOverlay' executed in 0.9485s.
# 'comparability_graph.forceOverlay' executed in 1.2067s.
# 'comparability_graph.assessEdges' executed in 0.0827s.
# 'comparability_graph.exportCompatFiles' executed in 1.1815s.
# 'comparability_graph.reportCompat' executed in 0.0313s.
#
# TESTING A/P RATIO =  1.1
# 'comparability_graph.reset' executed in 0.4562s.
# 'comparability_graph.findMaintenances' executed in 0.0555s.
# 'comparability_graph.findSplitings' executed in 0.1083s.
# 'comparability_graph.forceOverlay' executed in 1.9653s.
# 'comparability_graph.forceOverlay' executed in 0.9011s.
# 'comparability_graph.forceOverlay' executed in 1.2157s.
# 'comparability_graph.assessEdges' executed in 0.0833s.
# 'comparability_graph.exportCompatFiles' executed in 1.2403s.
# 'comparability_graph.reportCompat' executed in 0.0520s.
#
# TESTING A/P RATIO =  1.2
# 'comparability_graph.reset' executed in 0.4805s.
# 'comparability_graph.findMaintenances' executed in 0.0050s.
# 'comparability_graph.findSplitings' executed in 0.1067s.
# 'comparability_graph.forceOverlay' executed in 1.9675s.
# 'comparability_graph.forceOverlay' executed in 0.8975s.
# 'comparability_graph.forceOverlay' executed in 1.1704s.
# 'comparability_graph.assessEdges' executed in 0.0814s.
# 'comparability_graph.exportCompatFiles' executed in 1.2135s.
# 'comparability_graph.reportCompat' executed in 0.0312s.
#
# TESTING A/P RATIO =  1.3
# 'comparability_graph.reset' executed in 0.4590s.
# 'comparability_graph.findMaintenances' executed in 0.0050s.
# 'comparability_graph.findSplitings' executed in 0.1080s.
# 'comparability_graph.forceOverlay' executed in 1.9748s.
# 'comparability_graph.forceOverlay' executed in 0.8925s.
# 'comparability_graph.forceOverlay' executed in 1.1840s.
# 'comparability_graph.assessEdges' executed in 0.1157s.
# 'comparability_graph.exportCompatFiles' executed in 1.1503s.
# 'comparability_graph.reportCompat' executed in 0.0333s.
#
# TESTING A/P RATIO =  1.4
# 'comparability_graph.reset' executed in 0.4501s.
# 'comparability_graph.findMaintenances' executed in 0.0082s.
# 'comparability_graph.findSplitings' executed in 0.1076s.
# 'comparability_graph.forceOverlay' executed in 2.0337s.
# 'comparability_graph.forceOverlay' executed in 0.8948s.
# 'comparability_graph.forceOverlay' executed in 1.1778s.
# 'comparability_graph.assessEdges' executed in 0.0787s.
# 'comparability_graph.exportCompatFiles' executed in 1.1833s.
# 'comparability_graph.reportCompat' executed in 0.0268s.
#
# TESTING A/P RATIO =  1.5
# 'comparability_graph.reset' executed in 0.5096s.
# 'comparability_graph.findMaintenances' executed in 0.0055s.
# 'comparability_graph.findSplitings' executed in 0.1457s.
# 'comparability_graph.forceOverlay' executed in 1.9993s.
# 'comparability_graph.forceOverlay' executed in 0.8952s.
# 'comparability_graph.forceOverlay' executed in 1.1962s.
# 'comparability_graph.assessEdges' executed in 0.0763s.
# 'comparability_graph.exportCompatFiles' executed in 1.1975s.
# 'comparability_graph.reportCompat' executed in 0.0357s.
#
# TESTING A/P RATIO =  1.6
# 'comparability_graph.reset' executed in 0.4478s.
# 'comparability_graph.findMaintenances' executed in 0.0000s.
# 'comparability_graph.findSplitings' executed in 0.1016s.
# 'comparability_graph.forceOverlay' executed in 1.9665s.
# 'comparability_graph.forceOverlay' executed in 0.8871s.
# 'comparability_graph.forceOverlay' executed in 1.1871s.
# 'comparability_graph.assessEdges' executed in 0.1229s.
# 'comparability_graph.exportCompatFiles' executed in 1.1715s.
# 'comparability_graph.reportCompat' executed in 0.0301s.
#
# TESTING A/P RATIO =  1.7
# 'comparability_graph.reset' executed in 0.4545s.
# 'comparability_graph.findMaintenances' executed in 0.0045s.
# 'comparability_graph.findSplitings' executed in 0.1062s.
# 'comparability_graph.forceOverlay' executed in 2.0085s.
# 'comparability_graph.forceOverlay' executed in 0.8954s.
# 'comparability_graph.forceOverlay' executed in 1.1838s.
# 'comparability_graph.assessEdges' executed in 0.0802s.
# 'comparability_graph.exportCompatFiles' executed in 1.1407s.
# 'comparability_graph.reportCompat' executed in 0.0374s.
#
# TESTING A/P RATIO =  1.8
# 'comparability_graph.reset' executed in 0.5127s.
# 'comparability_graph.findMaintenances' executed in 0.0170s.
# 'comparability_graph.findSplitings' executed in 0.1070s.
# 'comparability_graph.forceOverlay' executed in 1.9487s.
# 'comparability_graph.forceOverlay' executed in 0.9081s.
# 'comparability_graph.forceOverlay' executed in 1.1937s.
# 'comparability_graph.assessEdges' executed in 0.0754s.
# 'comparability_graph.exportCompatFiles' executed in 1.2105s.
# 'comparability_graph.reportCompat' executed in 0.0213s.
#
# TESTING A/P RATIO =  1.9
# 'comparability_graph.reset' executed in 0.4642s.
# 'comparability_graph.findMaintenances' executed in 0.0058s.
# 'comparability_graph.findSplitings' executed in 0.1083s.
# 'comparability_graph.forceOverlay' executed in 1.9689s.
# 'comparability_graph.forceOverlay' executed in 0.8882s.
# 'comparability_graph.forceOverlay' executed in 1.1909s.
# 'comparability_graph.assessEdges' executed in 0.1241s.
# 'comparability_graph.exportCompatFiles' executed in 1.1734s.
# 'comparability_graph.reportCompat' executed in 0.0286s.
#
# TESTING A/P RATIO =  2.0
# 'comparability_graph.reset' executed in 0.4500s.
# 'comparability_graph.findMaintenances' executed in 0.0000s.
# 'comparability_graph.findSplitings' executed in 0.1218s.
# 'comparability_graph.forceOverlay' executed in 1.9789s.
# 'comparability_graph.forceOverlay' executed in 0.9406s.
# 'comparability_graph.forceOverlay' executed in 1.1602s.
# 'comparability_graph.assessEdges' executed in 0.0835s.
# 'comparability_graph.exportCompatFiles' executed in 1.1612s.
# 'comparability_graph.reportCompat' executed in 0.0306s.

# %%
for r in range(1,11):
    lmin = round(0.1 * r,2)

    print('\nTESTING Lmin = ', lmin)
    G_compat.reset()
    G_compat.findMaintenances()
    G_compat.findSplitings(threshold=lmin)
    # Aplica séries de buffers
    for b in [-20, -10]:
        G_compat.forceOverlay(buffer=b)
    # Sobreposição de isolados restantes
    G_compat.forceOverlay(buffer=0, use_all=True)

    G_compat.assessEdges(ground_truth_graph=truth_graph)

    G_compat.exportCompatFiles(BASENAME, NAME_C1, NAME_C2, save_files=False)
    G_compat.reportCompat(file=f'results/params/{BASENAME}_lmin{str(lmin).replace(".",",")}_report')
# Out:
# TESTING Lmin =  0.1
# 'comparability_graph.reset' executed in 0.5144s.
# 'comparability_graph.findMaintenances' executed in 0.0016s.
# 'comparability_graph.findSplitings' executed in 0.1345s.
# 'comparability_graph.forceOverlay' executed in 1.1321s.
# 'comparability_graph.forceOverlay' executed in 0.8748s.
# 'comparability_graph.forceOverlay' executed in 1.1724s.
# 'comparability_graph.assessEdges' executed in 0.0795s.
# 'comparability_graph.exportCompatFiles' executed in 1.2094s.
# 'comparability_graph.reportCompat' executed in 0.0233s.
#
# TESTING Lmin =  0.2
# 'comparability_graph.reset' executed in 0.4682s.
# 'comparability_graph.findMaintenances' executed in 0.0000s.
# 'comparability_graph.findSplitings' executed in 0.1799s.
# 'comparability_graph.forceOverlay' executed in 1.1880s.
# 'comparability_graph.forceOverlay' executed in 0.8803s.
# 'comparability_graph.forceOverlay' executed in 1.1423s.
# 'comparability_graph.assessEdges' executed in 0.1339s.
# 'comparability_graph.exportCompatFiles' executed in 1.1126s.
# 'comparability_graph.reportCompat' executed in 0.0316s.
#
# TESTING Lmin =  0.3
# 'comparability_graph.reset' executed in 0.4587s.
# 'comparability_graph.findMaintenances' executed in 0.0056s.
# 'comparability_graph.findSplitings' executed in 0.1199s.
# 'comparability_graph.forceOverlay' executed in 1.2313s.
# 'comparability_graph.forceOverlay' executed in 0.9345s.
# 'comparability_graph.forceOverlay' executed in 1.1675s.
# 'comparability_graph.assessEdges' executed in 0.0780s.
# 'comparability_graph.exportCompatFiles' executed in 1.1163s.
# 'comparability_graph.reportCompat' executed in 0.0228s.
#
# TESTING Lmin =  0.4
# 'comparability_graph.reset' executed in 0.5335s.
# 'comparability_graph.findMaintenances' executed in 0.0168s.
# 'comparability_graph.findSplitings' executed in 0.1202s.
# 'comparability_graph.forceOverlay' executed in 1.2684s.
# 'comparability_graph.forceOverlay' executed in 0.8795s.
# 'comparability_graph.forceOverlay' executed in 1.1559s.
# 'comparability_graph.assessEdges' executed in 0.0745s.
# 'comparability_graph.exportCompatFiles' executed in 1.1248s.
# 'comparability_graph.reportCompat' executed in 0.0285s.
#
# TESTING Lmin =  0.5
# 'comparability_graph.reset' executed in 0.5101s.
# 'comparability_graph.findMaintenances' executed in 0.0047s.
# 'comparability_graph.findSplitings' executed in 0.1113s.
# 'comparability_graph.forceOverlay' executed in 1.3747s.
# 'comparability_graph.forceOverlay' executed in 0.8837s.
# 'comparability_graph.forceOverlay' executed in 1.1612s.
# 'comparability_graph.assessEdges' executed in 0.0778s.
# 'comparability_graph.exportCompatFiles' executed in 1.2062s.
# 'comparability_graph.reportCompat' executed in 0.0489s.
#
# TESTING Lmin =  0.6
# 'comparability_graph.reset' executed in 0.4777s.
# 'comparability_graph.findMaintenances' executed in 0.0056s.
# 'comparability_graph.findSplitings' executed in 0.1101s.
# 'comparability_graph.forceOverlay' executed in 1.5476s.
# 'comparability_graph.forceOverlay' executed in 0.8865s.
# 'comparability_graph.forceOverlay' executed in 1.1731s.
# 'comparability_graph.assessEdges' executed in 0.1079s.
# 'comparability_graph.exportCompatFiles' executed in 1.1432s.
# 'comparability_graph.reportCompat' executed in 0.0259s.
#
# TESTING Lmin =  0.7
# 'comparability_graph.reset' executed in 0.4649s.
# 'comparability_graph.findMaintenances' executed in 0.0000s.
# 'comparability_graph.findSplitings' executed in 0.1667s.
# 'comparability_graph.forceOverlay' executed in 1.7339s.
# 'comparability_graph.forceOverlay' executed in 0.8934s.
# 'comparability_graph.forceOverlay' executed in 1.1579s.
# 'comparability_graph.assessEdges' executed in 0.0661s.
# 'comparability_graph.exportCompatFiles' executed in 1.1839s.
# 'comparability_graph.reportCompat' executed in 0.0332s.
#
# TESTING Lmin =  0.8
# 'comparability_graph.reset' executed in 0.4570s.
# 'comparability_graph.findMaintenances' executed in 0.0049s.
# 'comparability_graph.findSplitings' executed in 0.1057s.
# 'comparability_graph.forceOverlay' executed in 1.9763s.
# 'comparability_graph.forceOverlay' executed in 0.8938s.
# 'comparability_graph.forceOverlay' executed in 1.1798s.
# 'comparability_graph.assessEdges' executed in 0.0737s.
# 'comparability_graph.exportCompatFiles' executed in 1.2056s.
# 'comparability_graph.reportCompat' executed in 0.0291s.
#
# TESTING Lmin =  0.9
# 'comparability_graph.reset' executed in 0.5246s.
# 'comparability_graph.findMaintenances' executed in 0.0078s.
# 'comparability_graph.findSplitings' executed in 0.0940s.
# 'comparability_graph.forceOverlay' executed in 2.3082s.
# 'comparability_graph.forceOverlay' executed in 0.8874s.
# 'comparability_graph.forceOverlay' executed in 1.1709s.
# 'comparability_graph.assessEdges' executed in 0.1335s.
# 'comparability_graph.exportCompatFiles' executed in 1.1953s.
# 'comparability_graph.reportCompat' executed in 0.0274s.
#
# TESTING Lmin =  1.0
# 'comparability_graph.reset' executed in 0.4444s.
# 'comparability_graph.findMaintenances' executed in 0.0167s.
# 'comparability_graph.findSplitings' executed in 0.0667s.
# 'comparability_graph.forceOverlay' executed in 5.0949s.
# 'comparability_graph.forceOverlay' executed in 0.8979s.
# 'comparability_graph.forceOverlay' executed in 1.1693s.
# 'comparability_graph.assessEdges' executed in 0.0748s.
# 'comparability_graph.exportCompatFiles' executed in 1.1997s.
# 'comparability_graph.reportCompat' executed in 0.0333s.

# %%
df_apr = readMetrics(BASENAME, 'apr')
df_lmin = readMetrics(BASENAME, 'lmin')

# %%
from matplotlib import pyplot as plt
from matplotlib.ticker import MaxNLocator
params = {'mathtext.default': 'regular' , 'font.family':'Roboto'} 
plt.rcParams.update(params)
import seaborn as sns

labels = {
    'Inconsistent maintenance': 'Inconsistent\nmaintenance',
    'Inconsistent splitting':'Inconsistent\nsplitting',
    'Unconnected polygons':'Unconnected\npolygons',
    'Persistent unconnected':'Persistent\nunconnected',
    'Large redesigns':'Large\nredesigns',
    'recall': 'Recall\n(×1000)',
    'precision': 'Precision\n(×1000)',
    'f1_score': 'F1-Score\n(×1000)'
}

fig, ax = plt.subplots(2,len(df_apr.columns)-1,figsize=(15, 4), dpi=150)

for j, c in enumerate([i for i in df_apr.columns if i != 'A/P ratio']):
    i = (0,j)
    group_df = df_apr[['A/P ratio', c]]
    sns.lineplot(x='A/P ratio',y=c, data=group_df, color='blue', ax=ax[i], marker='None')

    # Anotações
    coords = [(x, y) for x,y in zip(group_df['A/P ratio'], group_df[c])]
    t=None
    for coord in coords[::2]:
        if coord[1]!=t:
            t = ax[i].annotate(f'{round(coord[1],0):n}', fontsize=4, xy=coord, textcoords='data', ha='center', va='center', color='white')
            t.set_bbox(dict(facecolor='white', alpha=1, linewidth=0, boxstyle='round,pad=0.8'))
            t = coord[1]
    t=None
    for coord in coords[::2]:
        if coord[1]!=t:
            ax[i].annotate(f'{round(coord[1],0):n}', fontsize=7, color='blue', xy=coord, textcoords='data', ha='center', va='center',zorder=5, fontweight='medium')
            t = coord[1]

    ax[i].set_title(labels[c], fontsize=13, ha='left', x=0)
    ax[i].xaxis.set_label_text('')

    ax[i].xaxis.set_ticks(group_df['A/P ratio'].to_list()[::2])
    ax[i].tick_params(axis='x', color='white', labelcolor='black', labelsize=9, rotation=90, pad=-2)

    [t.set_color('#aaaaaa') for t in ax[i].yaxis.get_ticklabels()]
    [t.set_va('bottom') for t in ax[i].yaxis.get_ticklabels()]
    ax[i].yaxis.set_major_locator(MaxNLocator(integer=True))
    ax[i].yaxis.set_ticklabels([t for t in ax[i].yaxis.get_ticklabels()])
    #ax[i].xaxis.set_ticklabels([])
    ax[i].yaxis.set_ticklabels([])
    ax[i].yaxis.set_label_text('')
    ax[i].tick_params(axis='y', color='white')

    if j==0:
        ax[i].set_ylabel('A/P', loc='top', va='top', fontsize=12, fontweight='medium')
        #ax[i].yaxis.set_label_text(r'A/P')
        ax[i].yaxis.label.set_color('blue')
        ax[i].yaxis.label.set_rotation(0)

    ax[i].grid(axis='y', visible=True, color='#eeeeee')
    ax[i].grid(axis='x', visible=True, color='#eeeeee')
    ax[i].set_facecolor("white")

for j, c in enumerate([i for i in df_lmin.columns if i != 'Lmin']):
    i = (1,j)
    group_df = df_lmin[['Lmin', c]]
    sns.lineplot(x='Lmin',y=c, data=group_df, color='deeppink', ax=ax[i], marker='None')

    # Anotações
    coords = [(x, y) for x,y in zip(group_df['Lmin'], group_df[c])]
    t=None
    for coord in coords:
        if coord[1]!=t:
            t = ax[i].annotate(f'{round(coord[1],0):n}', fontsize=4, xy=coord, textcoords='data', ha='center', va='center', color='white')
            t.set_bbox(dict(facecolor='white', alpha=1, linewidth=0, boxstyle='round,pad=0.8'))
            t = coord[1]
    t=None
    for coord in coords:
        if coord[1]!=t:
            ax[i].annotate(f'{round(coord[1],0):n}', fontsize=7, color='deeppink', xy=coord, textcoords='data', ha='center', va='center',zorder=5, fontweight='medium')
            t = coord[1]

    #ax[i].set_title(c.replace(' ','\n').replace('nao\npuras','nao puras'), ha='left', x=0)
    ax[i].xaxis.set_label_text('')

    ax[i].xaxis.set_ticks(group_df['Lmin'].to_list())
    ax[i].tick_params(axis='x', color='white', labelcolor='black', labelsize=9, rotation=90, pad=-2)

    [t.set_color('#aaaaaa') for t in ax[i].yaxis.get_ticklabels()]
    [t.set_va('bottom') for t in ax[i].yaxis.get_ticklabels()]
    ax[i].yaxis.set_major_locator(MaxNLocator(integer=True))
    ax[i].yaxis.set_ticklabels([t for t in ax[i].yaxis.get_ticklabels()])
    #ax[i].xaxis.set_ticklabels([])
    ax[i].yaxis.set_ticklabels([])
    ax[i].yaxis.set_label_text('')
    ax[i].tick_params(axis='y', color='white')

    if j==0:
        ax[i].set_ylabel('$L_{min}$', loc='top', va='top', fontsize=12, fontweight='medium')
        #ax[i].yaxis.set_label_text('$L_{min}$')
        ax[i].yaxis.label.set_color('deeppink')
        ax[i].yaxis.label.set_rotation(0)

    ax[i].grid(axis='y', visible=True, color='#eeeeee')
    ax[i].grid(axis='x', visible=True, color='#eeeeee')
    ax[i].set_facecolor("white")

fig.tight_layout()
plt.savefig(f'docs/analise_params_{location}.png', bbox_inches='tight')
plt.show()

# %%
df_lmin.plot.scatter(x='recall', y='precision')
plt.savefig(f'docs/f1-score_lmin_{location}.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(1,1,figsize=(6, 6), dpi=150) # Adjust figure size as needed
sns.heatmap(df_lmin.corr(method='spearman'), annot=True, cmap='coolwarm', fmt=".2f", ax=ax, linewidth=.1, robust=True)
ax.set_title('Matriz de correlação (spearman)\n', fontsize=14, ha='left', x=0, weight='bold')
ax.tick_params(axis='y', color='white')
ax.tick_params(axis='x', color='white')
plt.savefig(f'docs/corr-spearman_lmin_{location}.png', bbox_inches='tight')
plt.show()

# %%
df_apr.plot.scatter(x='recall', y='precision')
plt.savefig(f'docs/f1-score_apr_{location}.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(1,1,figsize=(6, 6), dpi=150) # Adjust figure size as needed
sns.heatmap(df_apr.corr(method='spearman'), annot=True, cmap='coolwarm', fmt=".2f", ax=ax, linewidth=.1, robust=True)
ax.set_title('Matriz de correlação (spearman)\n', fontsize=14, ha='left', x=0, weight='bold')
ax.tick_params(axis='y', color='white')
ax.tick_params(axis='x', color='white')
plt.savefig(f'docs/corr-spearman_apr_{location}.png', bbox_inches='tight')
plt.show()
